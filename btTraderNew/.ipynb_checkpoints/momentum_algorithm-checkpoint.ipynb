# %%
# %load_ext zipline
# Out:
# The zipline extension is already loaded. To reload it, use:
#   %reload_ext zipline

# %%
# %zipline ingest --help
# Out:
# Usage: %zipline [OPTIONS]
#
#   Run a backtest for the given algorithm.
#
# Options:
#   -f, --algofile FILENAME         The file that contains the algorithm to run.
#   -t, --algotext TEXT             The algorithm script to run.
#   -D, --define TEXT               Define a name to be bound in the namespace
#                                   before executing the algotext. For example
#                                   '-Dname=value'. The value may be any python
#                                   expression. These are evaluated in order so
#                                   they may refer to previously defined names.
#   --data-frequency [minute|daily]
#                                   The data frequency of the simulation.
#                                   [default: daily]
#   --capital-base FLOAT            The starting capital for the simulation.
#                                   [default: 10000000.0]
#   -b, --bundle BUNDLE-NAME        The data bundle to use for the simulation.
#                                   [default: quandl]
#   --bundle-timestamp TIMESTAMP    The date to lookup data on or before.
#                                   [default: <current-time>]
#   -s, --start DATE                The start date of the simulation.
#   -e, --end DATE                  The end date of the simulation.
#   -o, --output FILENAME           The location to write the perf data. If this
#                                   is '-' the perf will be written to stdout.
#                                   [default: -]
#   --trading-calendar TRADING-CALENDAR
#                                   The calendar you want to use e.g. LSE. NYSE
#                                   is the default.
#   --print-algo / --no-print-algo  Print the algorithm to stdout.
#   --metrics-set TEXT              The metrics set to use. New metrics sets may
#                                   be registered in your extension.py.
#   --blotter TEXT                  The blotter to use.  [default: default]
#   --local-namespace / --no-local-namespace
#                                   Should the algorithm methods be resolved in
#                                   the local namespace.
#   --help                          Show this message and exit.

# %%
# %%zipline --bundle nse-bundle --trading-calendar XNSE --start '2018-10-24' --end '2019-07-31' -o nse_weekly.pickle
# from zipline.data import bundles
# import os
# import pandas as pd
# from zipline.data.bundles import register, load
# from zipline.data.bundles.csvdir import csvdir_equities
# from zipline.data.data_portal import DataPortal
# from zipline.api import schedule_function
# from zipline.pipeline.data import Column
# from zipline.pipeline.pipeline import Pipeline
# from zipline.pipeline.data import USEquityPricing
# from zipline.pipeline.engine import SimplePipelineEngine
# from zipline.pipeline.loaders import USEquityPricingLoader
# from trading_calendars.trading_calendar import TradingCalendar
# from trading_calendars import get_calendar
# import itertools
# from zipline.pipeline.filters import StaticAssets
# from zipline.utils.events import (
#   date_rules,
#   time_rules,
#   Always,
#   ComposedRule,
#   Never,
#   OncePerDay,
# )
# from zipline.api import (
#   attach_pipeline,
#   date_rules,
#   order_target_percent,
#   pipeline_output,
#   record,
#   schedule_function,
#   symbols,
#   symbol,
#   sid,
# )
#
# start_session=pd.Timestamp('2018-09-01', tz='utc')
# end_session=pd.Timestamp('2019-07-31', tz='utc')
# import numpy as np
# from scipy import stats
# from zipline.api import order_target, record, symbol
#
# register(
#   'nse-bundle',
#   csvdir_equities(
#     ["daily"],
#     '/Users/niteshchawla/Ownstuff/pythonProjects/btTraderNew/'
#   ),
#   calendar_name="XNSE",
#   start_session=start_session,
#   end_session=end_session
# )
#
# bundle=load('nse-bundle')
# all_assets=bundle.asset_finder.retrieve_all(bundle.asset_finder.sids)
# # create a python set
# symbols=set(
#   str(asset.symbol) for asset in bundle.asset_finder.retrieve_all(bundle.asset_finder.equities_sids)
# )
#
# list_symbols=list(symbols)
# # print(type(list_symbols))
# # print("list of symbols", list_symbols)
# data_por=DataPortal(bundle.asset_finder,
#                     get_calendar("XNSE"),
#                     bundle.equity_daily_bar_reader.first_trading_day,
#                     equity_minute_reader=bundle.equity_minute_bar_reader,
#                     equity_daily_reader=bundle.equity_daily_bar_reader,
#                     adjustment_reader=bundle.adjustment_reader)
#
# close_prices=data_por.get_spot_value(bundle.asset_finder.retrieve_all(bundle.asset_finder.equities_sids), 'close',
#                                      pd.Timestamp('2018-09-01', tz='utc'), 'daily')
# close_prices_list=data_por.get_spot_value(bundle.asset_finder.retrieve_all(bundle.asset_finder.equities_sids), 'close',
#                                           pd.Timestamp('2018-09-01', tz='utc'), 'daily')
#
# list_sids=list(bundle.asset_finder.sids)
#
#
# # print((close_prices))
#
#
# def _slope(ts):
#   x=np.arange(len(ts))
#   slope, intercept, r_value, p_value, std_err=stats.linregress(x, ts)
#   annualized_slope=(np.power(np.exp(slope), 250)-1)*100
#   return annualized_slope*(r_value**2)
#
#
# def initialize(context):
#   """
#   Called once at the start of the algorithm.
#   """
#   # Setting global parameters
#   # context.assets = symbol('3MINDIA')
#   context.market=symbol('NIFTY500')
#   context.market_window=200
#   context.momentum_window=90
#   context.minimum_momentum=30
#   context.number_of_stocks=10
#   # --------------------------
#
#   """Set
#   up
#   pipeline
#   engine"""
#
#   # Loader for pricing
#   pipeline_loader=USEquityPricingLoader(
#     bundle.equity_daily_bar_reader,
#     bundle.adjustment_reader,
#   )
#
#   def choose_loader(column):
#     if column in USEquityPricing.columns:
#       return pipeline_loader
#
#     raise ValueError(
#       'No PipelineLoader registered for column %s.'%column
#     )
#
#   engine=SimplePipelineEngine(
#     get_loader=choose_loader,
#     calendar=get_calendar("XNSE").all_sessions,
#     asset_finder=bundle.asset_finder,
#   )
#
#   pipe=make_pipeline()
#
#   results=engine.run_pipeline(pipe,
#                               pd.to_datetime('2018-09-03', utc=True),
#                               pd.to_datetime('2019-07-31', utc=True))
#
#   # print(results.head(1200))
#   context.pipeline_data=results
#   # print("type results",type(results))
#   # Create our dynamic stock selector.
#   attach_pipeline(pipe, 'make_pipeline')
#
#   # Rebalance monthly
#   # schedule_function(my_rebalance, date_rules.month_start(), time_rules.market_open(hours=1))
#
#   """close_prices_list=data_por.get_spot_value(bundle.asset_finder.retrieve_all(bundle.asset_finder.equities_sids), 'close',
#                                           pd.Timestamp('2018-12-03', tz='utc'), 'daily')"""
#
#   # print("type of close prices", type(close_prices_list))
#   schedule_function(my_rebalance, date_rules.week_end(days_offset=2))
#   #schedule_function(my_rebalance, date_rules.month_end())
#
#
# #
#
#
# def make_pipeline():
#   """
#   This will return the top 500 US stocks by market cap, dynically updated.
#   """
#   # Base universe set to the Q500US
#   base_universe=(StaticAssets(all_assets))
#
#   # print(type(base_universe))
#   yesterday_close=close_prices_list
#
#   pipe=Pipeline(
#     screen=base_universe,
#     columns={
#       'close': USEquityPricing.close.latest,
#       'volume': USEquityPricing.volume.latest,
#       'open': USEquityPricing.open.latest,
#     }
#   )
#   return pipe
#
#
# def get_change(current, previous):
#   if current==previous:
#     return 100.0
#   try:
#     return ((current-previous)/previous)*100.0
#   except ZeroDivisionError:
#     return 0
#
#
# def before_trading_start(context, data):
#   print("inside before trading start")
#   # context.pipeline_data=pipeline_output(name='make_pipeline')
#
#
# def handle_data(context, data):
#   # context.pipeline_data=pipeline_output('make_pipeline')
#   # window_1 = data.history(context.assets,'high',1, '1d')
#   # print(window_1)
#   # schedule_function(my_rebalance(context, data), date_rules.week_end(days_offset=3))
#   pass
#
#
# def my_rebalance(context, data):
#   """
#   Our monthly rebalancing
#   """
#   # context.pipeline_data=pipeline_output('us_500')
#   # context.output=pipeline_output('us_500')  # update the current top 500 us stocks
#   # context.pipeline_data=pipeline_output('us_500')
#   algo_run_timestamp=str(context.datetime)+"T00:00.000000000"
#   print("has hit rebalance on date", algo_run_timestamp)
#   market_history=data.history(context.market, "close", context.market_window, "1d")  ##NIFTY##
#   market_price_algo_day=market_history.get(algo_run_timestamp)
#   market_sma_200=data.history(context.market, 'price', bar_count=200, frequency="1d").mean()
#   market_cond=market_price_algo_day>market_sma_200
#   market_chg=get_change(market_price_algo_day, market_sma_200)
#   print("market chg is", market_chg)
#   market_chg_cond=(market_chg<0.5)
#   if (market_chg_cond):
#     print(str(algo_run_timestamp))
#     print("nothing to buy")
#     return
#
#   my_dict={}
#   for x in range(len(list_sids)):
#     my_dict[x]=sid(list_sids[x])
#
#   context.security_list=list(my_dict.values())
#
#   momentum_list=np.log(data.history(context.security_list, "close", context.momentum_window, "1d")).apply(_slope)
#
#   # print("momentum list is", momentum_list.sort_values(ascending=False))
#   ranking_table=momentum_list.sort_values(ascending=False)  # Sorted
#
#   # print("price at a particular time",market_history.get(algo_run_timestamp))
#
#   # print("market history",market_history)
#   # market details
#   print("Nifty current price and 200Sma", market_price_algo_day, market_sma_200)
#   buy_list=ranking_table[:context.number_of_stocks]  # These we want to buy
#   print("buy list", buy_list)
#   print("context portfolio positions", context.portfolio.positions)
#   # Let's trade!
#   for security in context.portfolio.positions:
#     if security not in buy_list:
#       print("making this", security, 0)
#       order_target(security, 0)  # If a stock in the portfolio is not in buy list, sell it!
#
#   for security in context.security_list:
#     if security in buy_list:
#       sma_100=data.history(security, 'price', bar_count=100, frequency="1d").mean()
#       sma_50=data.history(security, 'price', bar_count=50, frequency="1d").mean()
#       print("security details", security)
#
#       if buy_list[security]<context.minimum_momentum:
#         weight=0.0
#       else:
#         weight=1.0/context.number_of_stocks  # Equal size to keep simple
#       cond1=sma_50>sma_100
#       cond2=market_price_algo_day>market_sma_200
#       print("security 50 and 100 sma", sma_50, sma_100)
#
#       if (cond1 and cond2):
#         order_target_percent(security, weight)  # Trade!
#         print("ordering this", security)
# Out:
# <string>:51: UserWarning: Overwriting bundle with name 'nse-bundle'
# has hit rebalance on date 2018-10-31 10:00:00+00:00T00:00.000000000
# market chg is -6.021154406294759
# 2018-10-31 10:00:00+00:00T00:00.000000000
# nothing to buy
# has hit rebalance on date 2018-11-30 10:00:00+00:00T00:00.000000000
# market chg is -1.4465661796670133
# 2018-11-30 10:00:00+00:00T00:00.000000000
# nothing to buy
# has hit rebalance on date 2018-12-31 10:00:00+00:00T00:00.000000000
# market chg is -0.6336151170405089
# 2018-12-31 10:00:00+00:00T00:00.000000000
# nothing to buy
# has hit rebalance on date 2019-01-31 10:00:00+00:00T00:00.000000000
# market chg is -2.4606561829263467
# 2019-01-31 10:00:00+00:00T00:00.000000000
# nothing to buy
# has hit rebalance on date 2019-02-28 10:00:00+00:00T00:00.000000000
# market chg is -2.5225823899520154
# 2019-02-28 10:00:00+00:00T00:00.000000000
# nothing to buy
# has hit rebalance on date 2019-03-29 10:00:00+00:00T00:00.000000000
# market chg is 4.983905507858208
# Nifty current price and 200Sma 9663.7 9204.934749999997
# buy list Equity(478 [VAKRANGEE])     261.757680
# Equity(1 [AAVAS])           219.024779
# Equity(299 [MANAPPURAM])    205.020047
# Equity(30 [ASTRAZEN])       193.402131
# Equity(365 [PRAJIND])       190.206307
# Equity(227 [INOXLEISUR])    177.286273
# Equity(474 [UJJIVAN])       151.348499
# Equity(49 [BATAINDIA])      138.460058
# Equity(498 [YESBANK])       136.355755
# Equity(44 [BALRAMCHIN])     109.185981
# dtype: float64
# context portfolio positions {}
# security details Equity(1 [AAVAS])
# security 50 and 100 sma 992.4830000000003 884.579
# ordering this Equity(1 [AAVAS])
# security details Equity(30 [ASTRAZEN])
# security 50 and 100 sma 1822.852 1664.5824999999988
# ordering this Equity(30 [ASTRAZEN])
# security details Equity(44 [BALRAMCHIN])
# security 50 and 100 sma 120.72300000000001 113.0865
# ordering this Equity(44 [BALRAMCHIN])
# security details Equity(49 [BATAINDIA])
# security 50 and 100 sma 1259.8580000000002 1164.5649999999998
# ordering this Equity(49 [BATAINDIA])
# security details Equity(227 [INOXLEISUR])
# security 50 and 100 sma 277.68498 254.25949000000003
# ordering this Equity(227 [INOXLEISUR])
# security details Equity(299 [MANAPPURAM])
# security 50 and 100 sma 109.281 98.99349999999998
# ordering this Equity(299 [MANAPPURAM])
# security details Equity(365 [PRAJIND])
# security 50 and 100 sma 142.66098000000002 128.76399
# ordering this Equity(365 [PRAJIND])
# security details Equity(474 [UJJIVAN])
# security 50 and 100 sma 298.198 271.7115
# ordering this Equity(474 [UJJIVAN])
# security details Equity(478 [VAKRANGEE])
# security 50 and 100 sma 46.174 39.50798999999999
# ordering this Equity(478 [VAKRANGEE])
# security details Equity(498 [YESBANK])
# security 50 and 100 sma 219.02500000000003 203.87400000000002
# ordering this Equity(498 [YESBANK])
# has hit rebalance on date 2019-04-30 10:00:00+00:00T00:00.000000000
# market chg is 4.536439388365097
# Nifty current price and 200Sma 9664.3 9244.910249999997
# buy list Equity(240 [J&KBANK])       331.608966
# Equity(104 [DBL])           323.004495
# Equity(478 [VAKRANGEE])     296.208258
# Equity(30 [ASTRAZEN])       244.665400
# Equity(1 [AAVAS])           224.120588
# Equity(44 [BALRAMCHIN])     177.817796
# Equity(429 [SUNTECK])       170.104280
# Equity(96 [CREDITACC])      163.950616
# Equity(299 [MANAPPURAM])    160.394872
# Equity(498 [YESBANK])       147.510112
# dtype: float64
# context portfolio positions {Equity(1 [AAVAS]): Position({'asset': Equity(1 [AAVAS]), 'amount': 865, 'last_sale_date': Timestamp('2019-04-30 10:00:00+0000', tz='UTC'), 'last_sale_price': 1198.3500000000001, 'cost_basis': 1161.5815}), Equity(498 [YESBANK]): Position({'asset': Equity(498 [YESBANK]), 'amount': 3635, 'last_sale_date': Timestamp('2019-04-30 10:00:00+0000', tz='UTC'), 'last_sale_price': 168.0, 'cost_basis': 276.03895000000006}), Equity(227 [INOXLEISUR]): Position({'asset': Equity(227 [INOXLEISUR]), 'amount': 3035, 'last_sale_date': Timestamp('2019-04-30 10:00:00+0000', tz='UTC'), 'last_sale_price': 313.7, 'cost_basis': 325.56370000000004}), Equity(30 [ASTRAZEN]): Position({'asset': Equity(30 [ASTRAZEN]), 'amount': 502, 'last_sale_date': Timestamp('2019-04-30 10:00:00+0000', tz='UTC'), 'last_sale_price': 2358.0, 'cost_basis': 2011.956475}), Equity(49 [BATAINDIA]): Position({'asset': Equity(49 [BATAINDIA]), 'amount': 711, 'last_sale_date': Timestamp('2019-04-30 10:00:00+0000', tz='UTC'), 'last_sale_price': 1454.0, 'cost_basis': 1388.044675}), Equity(474 [UJJIVAN]): Position({'asset': Equity(474 [UJJIVAN]), 'amount': 2875, 'last_sale_date': Timestamp('2019-04-30 10:00:00+0000', tz='UTC'), 'last_sale_price': 324.90000000000003, 'cost_basis': 344.923375}), Equity(299 [MANAPPURAM]): Position({'asset': Equity(299 [MANAPPURAM]), 'amount': 7980, 'last_sale_date': Timestamp('2019-04-30 10:00:00+0000', tz='UTC'), 'last_sale_price': 117.95, 'cost_basis': 125.01347500000001}), Equity(44 [BALRAMCHIN]): Position({'asset': Equity(44 [BALRAMCHIN]), 'amount': 7293, 'last_sale_date': Timestamp('2019-04-30 10:00:00+0000', tz='UTC'), 'last_sale_price': 150.6, 'cost_basis': 139.620775}), Equity(365 [PRAJIND]): Position({'asset': Equity(365 [PRAJIND]), 'amount': 6447, 'last_sale_date': Timestamp('2019-04-30 10:00:00+0000', tz='UTC'), 'last_sale_price': 136.75, 'cost_basis': 154.52822500000002}), Equity(478 [VAKRANGEE]): Position({'asset': Equity(478 [VAKRANGEE]), 'amount': 19880, 'last_sale_date': Timestamp('2019-04-30 10:00:00+0000', tz='UTC'), 'last_sale_price': 62.7, 'cost_basis': 51.176575})}
# making this Equity(227 [INOXLEISUR]) 0
# making this Equity(49 [BATAINDIA]) 0
# making this Equity(474 [UJJIVAN]) 0
# making this Equity(365 [PRAJIND]) 0
# security details Equity(1 [AAVAS])
# security 50 and 100 sma 1108.3210000000001 970.0950000000003
# ordering this Equity(1 [AAVAS])
# security details Equity(30 [ASTRAZEN])
# security 50 and 100 sma 2007.0200000000007 1769.5104999999996
# ordering this Equity(30 [ASTRAZEN])
# security details Equity(44 [BALRAMCHIN])
# security 50 and 100 sma 134.19099999999997 119.65699999999998
# ordering this Equity(44 [BALRAMCHIN])
# security details Equity(96 [CREDITACC])
# security 50 and 100 sma 476.18595999999997 432.3809800000001
# ordering this Equity(96 [CREDITACC])
# security details Equity(104 [DBL])
# security 50 and 100 sma 574.914 483.8219999999998
# ordering this Equity(104 [DBL])
# security details Equity(240 [J&KBANK])
# security 50 and 100 sma 50.422 44.2075
# ordering this Equity(240 [J&KBANK])
# security details Equity(299 [MANAPPURAM])
# security 50 and 100 sma 118.43700000000001 105.92050000000003
# ordering this Equity(299 [MANAPPURAM])
# security details Equity(429 [SUNTECK])
# security 50 and 100 sma 429.53399999999993 387.389
# ordering this Equity(429 [SUNTECK])
# security details Equity(478 [VAKRANGEE])
# security 50 and 100 sma 51.599000000000004 45.711490000000005
# ordering this Equity(478 [VAKRANGEE])
# security details Equity(498 [YESBANK])
# security 50 and 100 sma 243.114 214.60600000000002
# ordering this Equity(498 [YESBANK])
# has hit rebalance on date 2019-05-31 10:00:00+00:00T00:00.000000000
# market chg is 5.918954318970495
# Nifty current price and 200Sma 9805.05 9257.125000000002
# buy list Equity(1 [AAVAS])           365.494121
# Equity(346 [ORIENTCEM])     363.352007
# Equity(201 [IBREALEST])     347.972029
# Equity(240 [J&KBANK])       307.338190
# Equity(107 [DCMSHRIRAM])    263.357510
# Equity(350 [PCJEWELLER])    223.041415
# Equity(21 [APLAPOLLO])      209.720269
# Equity(220 [INDIGO])        201.105955
# Equity(429 [SUNTECK])       198.984848
# Equity(169 [GRUH])          191.473432
# dtype: float64
# context portfolio positions {Equity(96 [CREDITACC]): Position({'asset': Equity(96 [CREDITACC]), 'amount': 1896, 'last_sale_date': Timestamp('2019-05-31 10:00:00+0000', tz='UTC'), 'last_sale_price': 523.25, 'cost_basis': 527.2645}), Equity(1 [AAVAS]): Position({'asset': Equity(1 [AAVAS]), 'amount': 827, 'last_sale_date': Timestamp('2019-05-31 10:00:00+0000', tz='UTC'), 'last_sale_price': 1419.7, 'cost_basis': 1161.581545949214}), Equity(104 [DBL]): Position({'asset': Equity(104 [DBL]), 'amount': 1838, 'last_sale_date': Timestamp('2019-05-31 10:00:00+0000', tz='UTC'), 'last_sale_price': 579.2, 'cost_basis': 500.0509}), Equity(299 [MANAPPURAM]): Position({'asset': Equity(299 [MANAPPURAM]), 'amount': 8397, 'last_sale_date': Timestamp('2019-05-31 10:00:00+0000', tz='UTC'), 'last_sale_price': 134.8, 'cost_basis': 124.63586578242231}), Equity(44 [BALRAMCHIN]): Position({'asset': Equity(44 [BALRAMCHIN]), 'amount': 6577, 'last_sale_date': Timestamp('2019-05-31 10:00:00+0000', tz='UTC'), 'last_sale_price': 154.0, 'cost_basis': 139.62088386422383}), Equity(429 [SUNTECK]): Position({'asset': Equity(429 [SUNTECK]), 'amount': 2146, 'last_sale_date': Timestamp('2019-05-31 10:00:00+0000', tz='UTC'), 'last_sale_price': 497.05, 'cost_basis': 458.33004999999997}), Equity(240 [J&KBANK]): Position({'asset': Equity(240 [J&KBANK]), 'amount': 16303, 'last_sale_date': Timestamp('2019-05-31 10:00:00+0000', tz='UTC'), 'last_sale_price': 59.4, 'cost_basis': 60.631299999999996}), Equity(498 [YESBANK]): Position({'asset': Equity(498 [YESBANK]), 'amount': 5895, 'last_sale_date': Timestamp('2019-05-31 10:00:00+0000', tz='UTC'), 'last_sale_price': 147.8, 'cost_basis': 236.8575370229008}), Equity(478 [VAKRANGEE]): Position({'asset': Equity(478 [VAKRANGEE]), 'amount': 15797, 'last_sale_date': Timestamp('2019-05-31 10:00:00+0000', tz='UTC'), 'last_sale_price': 47.25, 'cost_basis': 51.17683346679749}), Equity(30 [ASTRAZEN]): Position({'asset': Equity(30 [ASTRAZEN]), 'amount': 421, 'last_sale_date': Timestamp('2019-05-31 10:00:00+0000', tz='UTC'), 'last_sale_price': 1969.2, 'cost_basis': 2011.95666739905})}
# making this Equity(96 [CREDITACC]) 0
# making this Equity(104 [DBL]) 0
# making this Equity(299 [MANAPPURAM]) 0
# making this Equity(44 [BALRAMCHIN]) 0
# making this Equity(498 [YESBANK]) 0
# making this Equity(478 [VAKRANGEE]) 0
# making this Equity(30 [ASTRAZEN]) 0
# security details Equity(1 [AAVAS])
# security 50 and 100 sma 1261.0469999999996 1099.7035
# ordering this Equity(1 [AAVAS])
# security details Equity(21 [APLAPOLLO])
# security 50 and 100 sma 1511.5950000000005 1343.8485
# ordering this Equity(21 [APLAPOLLO])
# security details Equity(107 [DCMSHRIRAM])
# security 50 and 100 sma 464.796 416.81550000000004
# ordering this Equity(107 [DCMSHRIRAM])
# security details Equity(169 [GRUH])
# security 50 and 100 sma 295.564 270.1035
# ordering this Equity(169 [GRUH])
# security details Equity(201 [IBREALEST])
# security 50 and 100 sma 106.479 91.9585
# ordering this Equity(201 [IBREALEST])
# security details Equity(220 [INDIGO])
# security 50 and 100 sma 1492.2320000000002 1325.5599999999997
# ordering this Equity(220 [INDIGO])
# security details Equity(240 [J&KBANK])
# security 50 and 100 sma 57.236999999999995 48.667999999999985
# ordering this Equity(240 [J&KBANK])
# security details Equity(346 [ORIENTCEM])
# security 50 and 100 sma 99.14399999999999 86.77949000000004
# ordering this Equity(346 [ORIENTCEM])
# security details Equity(350 [PCJEWELLER])
# security 50 and 100 sma 103.31398000000002 89.00997999999998
# ordering this Equity(350 [PCJEWELLER])
# security details Equity(429 [SUNTECK])
# security 50 and 100 sma 472.13499999999993 413.48400000000015
# ordering this Equity(429 [SUNTECK])
# has hit rebalance on date 2019-06-28 10:00:00+00:00T00:00.000000000
# market chg is 4.4602333175410624
# Nifty current price and 200Sma 9657.95 9245.575750000004
# buy list Equity(201 [IBREALEST])     316.123447
# Equity(346 [ORIENTCEM])     290.646627
# Equity(229 [INTELLECT])     250.810322
# Equity(297 [MAHSCOOTER])    219.580660
# Equity(1 [AAVAS])           213.902042
# Equity(363 [PNCINFRA])      194.597031
# Equity(175 [GUJGASLTD])     194.121933
# Equity(220 [INDIGO])        174.267972
# Equity(261 [JUSTDIAL])      165.271448
# Equity(183 [HDFCAMC])       162.931866
# dtype: float64
# context portfolio positions {Equity(1 [AAVAS]): Position({'asset': Equity(1 [AAVAS]), 'amount': 699, 'last_sale_date': Timestamp('2019-06-28 10:00:00+0000', tz='UTC'), 'last_sale_price': 1499.3, 'cost_basis': 1161.581729067955}), Equity(169 [GRUH]): Position({'asset': Equity(169 [GRUH]), 'amount': 3121, 'last_sale_date': Timestamp('2019-06-28 10:00:00+0000', tz='UTC'), 'last_sale_price': 276.1, 'cost_basis': 317.20952500000004}), Equity(107 [DCMSHRIRAM]): Position({'asset': Equity(107 [DCMSHRIRAM]), 'amount': 1786, 'last_sale_date': Timestamp('2019-06-28 10:00:00+0000', tz='UTC'), 'last_sale_price': 562.3000000000001, 'cost_basis': 531.716725}), Equity(429 [SUNTECK]): Position({'asset': Equity(429 [SUNTECK]), 'amount': 1995, 'last_sale_date': Timestamp('2019-06-28 10:00:00+0000', tz='UTC'), 'last_sale_price': 435.25, 'cost_basis': 458.330125689223}), Equity(240 [J&KBANK]): Position({'asset': Equity(240 [J&KBANK]), 'amount': 16691, 'last_sale_date': Timestamp('2019-06-28 10:00:00+0000', tz='UTC'), 'last_sale_price': 40.25, 'cost_basis': 60.590599053382064}), Equity(21 [APLAPOLLO]): Position({'asset': Equity(21 [APLAPOLLO]), 'amount': 611, 'last_sale_date': Timestamp('2019-06-28 10:00:00+0000', tz='UTC'), 'last_sale_price': 1501.15, 'cost_basis': 1575.3883000000003}), Equity(201 [IBREALEST]): Position({'asset': Equity(201 [IBREALEST]), 'amount': 7903, 'last_sale_date': Timestamp('2019-06-28 10:00:00+0000', tz='UTC'), 'last_sale_price': 113.85000000000001, 'cost_basis': 124.71332500000001}), Equity(346 [ORIENTCEM]): Position({'asset': Equity(346 [ORIENTCEM]), 'amount': 8488, 'last_sale_date': Timestamp('2019-06-28 10:00:00+0000', tz='UTC'), 'last_sale_price': 102.2, 'cost_basis': 119.01047500000001}), Equity(220 [INDIGO]): Position({'asset': Equity(220 [INDIGO]), 'amount': 591, 'last_sale_date': Timestamp('2019-06-28 10:00:00+0000', tz='UTC'), 'last_sale_price': 1557.95, 'cost_basis': 1692.1966750000001}), Equity(350 [PCJEWELLER]): Position({'asset': Equity(350 [PCJEWELLER]), 'amount': 12859, 'last_sale_date': Timestamp('2019-06-28 10:00:00+0000', tz='UTC'), 'last_sale_price': 45.4, 'cost_basis': 75.0385})}
# making this Equity(169 [GRUH]) 0
# making this Equity(107 [DCMSHRIRAM]) 0
# making this Equity(429 [SUNTECK]) 0
# making this Equity(240 [J&KBANK]) 0
# making this Equity(21 [APLAPOLLO]) 0
# making this Equity(350 [PCJEWELLER]) 0
# security details Equity(1 [AAVAS])
# security 50 and 100 sma 1369.931 1208.9595000000002
# ordering this Equity(1 [AAVAS])
# security details Equity(175 [GUJGASLTD])
# security 50 and 100 sma 169.328 152.29498999999996
# ordering this Equity(175 [GUJGASLTD])
# security details Equity(183 [HDFCAMC])
# security 50 and 100 sma 1734.4630000000004 1586.0210000000004
# ordering this Equity(183 [HDFCAMC])
# security details Equity(201 [IBREALEST])
# security 50 and 100 sma 114.63300000000001 98.01799999999999
# ordering this Equity(201 [IBREALEST])
# security details Equity(220 [INDIGO])
# security 50 and 100 sma 1576.1589999999999 1418.3854999999999
# ordering this Equity(220 [INDIGO])
# security details Equity(229 [INTELLECT])
# security 50 and 100 sma 243.05100000000002 216.94749999999996
# ordering this Equity(229 [INTELLECT])
# security details Equity(261 [JUSTDIAL])
# security 50 and 100 sma 667.4630000000001 606.269
# ordering this Equity(261 [JUSTDIAL])
# security details Equity(297 [MAHSCOOTER])
# security 50 and 100 sma 4124.887 3723.4994999999994
# ordering this Equity(297 [MAHSCOOTER])
# security details Equity(346 [ORIENTCEM])
# security 50 and 100 sma 107.4 92.89048999999997
# ordering this Equity(346 [ORIENTCEM])
# security details Equity(363 [PNCINFRA])
# security 50 and 100 sma 176.4560000000001 160.5404900000001
# ordering this Equity(363 [PNCINFRA])
# has hit rebalance on date 2019-07-31 10:00:00+00:00T00:00.000000000
# market chg is -2.1495784754711935
# 2019-07-31 10:00:00+00:00T00:00.000000000
# nothing to buy
#                            algo_volatility  algorithm_period_return     alpha  \
# 2018-10-24 10:00:00+00:00              NaN                 0.000000       NaN
# 2018-10-25 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-10-26 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-10-29 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-10-30 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-10-31 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-01 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-02 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-05 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-06 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-07 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-09 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-12 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-13 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-14 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-15 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-16 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-19 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-20 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-21 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-22 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-26 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-27 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-28 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-29 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-11-30 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-12-03 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018-12-04 10:00:00+00:00         0.000000                 0.000000  0.000000
# 2018
# 2019-06-28 10:00:00+00:00                    0.0
# 2019-07-01 10:00:00+00:00                    0.0
# 2019-07-02 10:00:00+00:00                    0.0
# 2019-07-03 10:00:00+00:00                    0.0
# 2019-07-04 10:00:00+00:00                    0.0
# 2019-07-05 10:00:00+00:00                    0.0
# 2019-07-08 10:00:00+00:00                    0.0
# 2019-07-09 10:00:00+00:00                    0.0
# 2019-07-10 10:00:00+00:00                    0.0
# 2019-07-11 10:00:00+00:00                    0.0
# 2019-07-12 10:00:00+00:00                    0.0
# 2019-07-15 10:00:00+00:00                    0.0
# 2019-07-16 10:00:00+00:00                    0.0
# 2019-07-17 10:00:00+00:00                    0.0
# 2019-07-18 10:00:00+00:00                    0.0
# 2019-07-19 10:00:00+00:00                    0.0
# 2019-07-22 10:00:00+00:00                    0.0
# 2019-07-23 10:00:00+00:00                    0.0
# 2019-07-24 10:00:00+00:00                    0.0
# 2019-07-25 10:00:00+00:00                    0.0
# 2019-07-26 10:00:00+00:00                    0.0
# 2019-07-29 10:00:00+00:00                    0.0
# 2019-07-30 10:00:00+00:00                    0.0
# 2019-07-31 10:00:00+00:00                    0.0
#
# [190 rows x 37 columns]

# %%
import pandas as pd
perf = pd.read_pickle('nse_weekly.pickle') # read in perf DataFrame

# %%
perf.to_csv("results.csv")

# %%
for items in perf.orders.iteritems():
    if(items[1]):
        print(items)
# Out:
# (Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), [{'filled': 0, 'sid': Equity(1 [AAVAS]), 'created': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'amount': 865, 'id': 'b8ed3f5997044fe68da52e705f43b3fe', 'limit_reached': False, 'status': 0, 'reason': None, 'dt': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 0, 'stop': None, 'limit': None}, {'filled': 0, 'sid': Equity(30 [ASTRAZEN]), 'created': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'amount': 502, 'id': '4e8082c5c0b14833b8452f6aad95f450', 'limit_reached': False, 'status': 0, 'reason': None, 'dt': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 0, 'stop': None, 'limit': None}, {'filled': 0, 'sid': Equity(44 [BALRAMCHIN]), 'created': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'amount': 7293, 'id': '9978939ff8a448ff97a7f1ac299be34d', 'limit_reached': False, 'status': 0, 'reason': None, 'dt': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 0, 'stop': None, 'limit': None}, {'filled': 0, 'sid': Equity(49 [BATAINDIA]), 'created': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'amount': 711, 'id': '66b07d1a52b3450fa5dc17c70546932f', 'limit_reached': False, 'status': 0, 'reason': None, 'dt': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 0, 'stop': None, 'limit': None}, {'filled': 0, 'sid': Equity(227 [INOXLEISUR]), 'created': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'amount': 3035, 'id': '7748838c53cb4f5d923417c9edf86f37', 'limit_reached': False, 'status': 0, 'reason': None, 'dt': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 0, 'stop': None, 'limit': None}, {'filled': 0, 'sid': Equity(299 [MANAPPURAM]), 'created': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'amount': 7980, 'id': '559bf4383b234cd0a3f7928dc25800e9', 'limit_reached': False, 'status': 0, 'reason': None, 'dt': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 0, 'stop': None, 'limit': None}, {'filled': 0, 'sid': Equity(365 [PRAJIND]), 'created': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'amount': 6447, 'id': '54d25c9ffabd40f6bfedfc24ebeb84b9', 'limit_reached': False, 'status': 0, 'reason': None, 'dt': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 0, 'stop': None, 'limit': None}, {'filled': 0, 'sid': Equity(474 [UJJIVAN]), 'created': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'amount': 2875, 'id': '1cc8feead5d04f069efdb15766eeb906', 'limit_reached': False, 'status': 0, 'reason': None, 'dt': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 0, 'stop': None, 'limit': None}, {'filled': 0, 'sid': Equity(478 [VAKRANGEE]), 'created': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'amount': 19880, 'id': '676710ac7e684165803049c24eb43e0f', 'limit_reached': False, 'status': 0, 'reason': None, 'dt': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 0, 'stop': None, 'limit': None}, {'filled': 0, 'sid': Equity(498 [YESBANK]), 'created': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'amount': 3635, 'id': 'f2f78ca88a4840b6ac4b93611ac62763', 'limit_reached': False, 'status': 0, 'reason': None, 'dt': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 0, 'stop': None, 'limit': None}])
# (Timestamp('2019-04-01 10:00:00+0000', tz='UTC'), [{'filled': 865, 'sid': Equity(1 [AAVAS]), 'created': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'amount': 865, 'id': 'b8ed3f5997044fe68da52e705f43b3fe', 'limit_reached': False, 'status': 1, 'reason': None, 'dt': Timestamp('2019-04-01 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 0.865, 'stop': None, 'limit': None}, {'filled': 3635, 'sid': Equity(498 [YESBANK]), 'created': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'amount': 3635, 'id': 'f2f78ca88a4840b6ac4b93611ac62763', 'limit_reached': False, 'status': 1, 'reason': None, 'dt': Timestamp('2019-04-01 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 3.6350000000000002, 'stop': None, 'limit': None}, {'filled': 3035, 'sid': Equity(227 [INOXLEISUR]), 'created': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'amount': 3035, 'id': '7748838c53cb4f5d923417c9edf86f37', 'limit_reached': False, 'status': 1, 'reason': None, 'dt': Timestamp('2019-04-01 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 3.035, 'stop': None, 'limit': None}, {'filled': 19880, 'sid': Equity(478 [VAKRANGEE]), 'created': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'amount': 19880, 'id': '676710ac7e684165803049c24eb43e0f', 'limit_reached': False, 'status': 1, 'reason': None, 'dt': Timestamp('2019-04-01 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 19.88, 'stop': None, 'limit': None}, {'filled': 711, 'sid': Equity(49 [BATAINDIA]), 'created': Timestamp('2019-03-29 10:00:00+0000', tz='UTC'), 'amount':
 'limit_reached': False, 'status': 1, 'reason': None, 'dt': Timestamp('2019-07-01 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 0.611, 'stop': None, 'limit': None}, {'filled': 35, 'sid': Equity(346 [ORIENTCEM]), 'created': Timestamp('2019-06-28 10:00:00+0000', tz='UTC'), 'amount': 35, 'id': 'c9255bc7d9694a9cb440f5e6d431bf70', 'limit_reached': False, 'status': 1, 'reason': None, 'dt': Timestamp('2019-07-01 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 0.035, 'stop': None, 'limit': None}, {'filled': -31, 'sid': Equity(220 [INDIGO]), 'created': Timestamp('2019-06-28 10:00:00+0000', tz='UTC'), 'amount': -31, 'id': '573680f9df61453fa6b9a0ed400abdff', 'limit_reached': False, 'status': 1, 'reason': None, 'dt': Timestamp('2019-07-01 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 0.031, 'stop': None, 'limit': None}, {'filled': 189, 'sid': Equity(297 [MAHSCOOTER]), 'created': Timestamp('2019-06-28 10:00:00+0000', tz='UTC'), 'amount': 189, 'id': '193838e057634c5bb4974cdc6217d80e', 'limit_reached': False, 'status': 1, 'reason': None, 'dt': Timestamp('2019-07-01 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 0.189, 'stop': None, 'limit': None}, {'filled': -12859, 'sid': Equity(350 [PCJEWELLER]), 'created': Timestamp('2019-06-28 10:00:00+0000', tz='UTC'), 'amount': -12859, 'id': '54955a40d86f4950adda5519b8d6688e', 'limit_reached': False, 'status': 1, 'reason': None, 'dt': Timestamp('2019-07-01 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 12.859, 'stop': None, 'limit': None}, {'filled': 3281, 'sid': Equity(229 [INTELLECT]), 'created': Timestamp('2019-06-28 10:00:00+0000', tz='UTC'), 'amount': 3281, 'id': '598e2288bb5d4a159c68773bd1b11ef0', 'limit_reached': False, 'status': 1, 'reason': None, 'dt': Timestamp('2019-07-01 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 3.281, 'stop': None, 'limit': None}, {'filled': -3121, 'sid': Equity(169 [GRUH]), 'created': Timestamp('2019-06-28 10:00:00+0000', tz='UTC'), 'amount': -3121, 'id': '8e7e7247343047f4947f41ceeadf7dcf', 'limit_reached': False, 'status': 1, 'reason': None, 'dt': Timestamp('2019-07-01 10:00:00+0000', tz='UTC'), 'stop_reached': False, 'commission': 3.121, 'stop': None, 'limit': None}, {'filled': -1786, 'sid': Equity(107 [DCMSHRIRAM]), 'created': Timestamp('2019-06-28 10:00:00+0000', tz='UTC'), 'am ...

# %%
# transactions
for items in perf.transactions.iteritems():
    if(items[1]):
        print(items)
# Out:
# (Timestamp('2019-04-01 10:00:00+0000', tz='UTC'), [{'amount': 865, 'dt': Timestamp('2019-04-01 10:00:00+0000', tz='UTC'), 'sid': Equity(1 [AAVAS]), 'commission': None, 'price': 1161.5805, 'order_id': 'b8ed3f5997044fe68da52e705f43b3fe'}, {'amount': 3635, 'dt': Timestamp('2019-04-01 10:00:00+0000', tz='UTC'), 'sid': Equity(498 [YESBANK]), 'commission': None, 'price': 276.03795, 'order_id': 'f2f78ca88a4840b6ac4b93611ac62763'}, {'amount': 3035, 'dt': Timestamp('2019-04-01 10:00:00+0000', tz='UTC'), 'sid': Equity(227 [INOXLEISUR]), 'commission': None, 'price': 325.5627, 'order_id': '7748838c53cb4f5d923417c9edf86f37'}, {'amount': 19880, 'dt': Timestamp('2019-04-01 10:00:00+0000', tz='UTC'), 'sid': Equity(478 [VAKRANGEE]), 'commission': None, 'price': 51.175575, 'order_id': '676710ac7e684165803049c24eb43e0f'}, {'amount': 711, 'dt': Timestamp('2019-04-01 10:00:00+0000', tz='UTC'), 'sid': Equity(49 [BATAINDIA]), 'commission': None, 'price': 1388.0436750000001, 'order_id': '66b07d1a52b3450fa5dc17c70546932f'}, {'amount': 2875, 'dt': Timestamp('2019-04-01 10:00:00+0000', tz='UTC'), 'sid': Equity(474 [UJJIVAN]), 'commission': None, 'price': 344.922375, 'order_id': '1cc8feead5d04f069efdb15766eeb906'}, {'amount': 7980, 'dt': Timestamp('2019-04-01 10:00:00+0000', tz='UTC'), 'sid': Equity(299 [MANAPPURAM]), 'commission': None, 'price': 125.01247500000001, 'order_id': '559bf4383b234cd0a3f7928dc25800e9'}, {'amount': 7293, 'dt': Timestamp('2019-04-01 10:00:00+0000', tz='UTC'), 'sid': Equity(44 [BALRAMCHIN]), 'commission': None, 'price': 139.619775, 'order_id': '9978939ff8a448ff97a7f1ac299be34d'}, {'amount': 6447, 'dt': Timestamp('2019-04-01 10:00:00+0000', tz='UTC'), 'sid': Equity(365 [PRAJIND]), 'commission': None, 'price': 154.52722500000002, 'order_id': '54d25c9ffabd40f6bfedfc24ebeb84b9'}, {'amount': 502, 'dt': Timestamp('2019-04-01 10:00:00+0000', tz='UTC'), 'sid': Equity(30 [ASTRAZEN]), 'commission': None, 'price': 2011.955475, 'order_id': '4e8082c5c0b14833b8452f6aad95f450'}])
# (Timestamp('2019-05-02 10:00:00+0000', tz='UTC'), [{'amount': 1896, 'dt': Timestamp('2019-05-02 10:00:00+0000', tz='UTC'), 'sid': Equity(96 [CREDITACC]), 'commission': None, 'price': 527.2635, 'order_id': '24163ff465eb442f8b80fab74054f634'}, {'amount': -38, 'dt': Timestamp('2019-05-02 10:00:00+0000', tz='UTC'), 'sid': Equity
 'dt': Timestamp('2019-07-01 10:00:00+0000', tz='UTC'), 'sid': Equity(175 [GUJGASLTD]), 'commission': None, 'price': 171.835875, 'order_id': '68013feb1e1e4f95905205ea9a811075'}, {'amount': -16691, 'dt': Timestamp('2019-07-01 10:00:00+0000', tz='UTC'), 'sid': Equity(240 [J&KBANK]), 'commission': None, 'price': 40.9795, 'order_id': '4d192370138143e59716489df163dda4'}, {'amount': 422, 'dt': Timestamp('2019-07-01 10:00:00+0000', tz='UTC'), 'sid': Equity(183 [HDFCAMC]), 'commission': None, 'price': 2081.9894745, 'order_id': 'cddb82f5ec9845b5a6349c1175deb450'}])

# %%
for items in perf.pnl.iteritems():
    if(items[1]):
       
        print(items)
# Out:
# (Timestamp('2019-04-01 10:00:00+0000', tz='UTC'), -5057.8478999994695)
# (Timestamp('2019-04-02 10:00:00+0000', tz='UTC'), -52374.050000000745)
# (Timestamp('2019-04-03 10:00:00+0000', tz='UTC'), -121106.5)
# (Timestamp('2019-04-04 10:00:00+0000', tz='UTC'), -118763.09999999963)
# (Timestamp('2019-04-05 10:00:00+0000', tz='UTC'), 180004.69999999925)
# (Timestamp('2019-04-08 10:00:00+0000', tz='UTC'), -187088.40000000037)
# (Timestamp('2019-04-09 10:00:00+0000', tz='UTC'), 70065.90000000037)
# (Timestamp('2019-04-10 10:00:00+0000', tz='UTC'), 179860.24999999814)
# (Timestamp('2019-04-11 10:00:00+0000', tz='UTC'), 229053.45000000298)
# (Timestamp('2019-04-12 10:00:00+0000', tz='UTC'), 131857.09999999776)
# (Timestamp('2019-04-15 10:00:00+0000', tz='UTC'), 5212.10000000149)
# (Timestamp('2019-04-16 10:00:00+0000', tz='UTC'), -4361.300000000745)
# (Timestamp('2019-04-18 10:00:00+0000', tz='UTC'), -93866.24999999814)
# (Timestamp('2019-04-22 10:00:00+0000', tz='UTC'), -261459.6000000015)
# (Timestamp('2019-04-23 10:00:00+0000', tz='UTC'), -90533.44999999925)
# (Timestamp('2019-04-24 10:00:00+0000', tz='UTC'), 46911.300000000745)
# (Timestamp('2019-04-25 10:00:00+0000', tz='UTC'), 168641.8999999985)
# (Timestamp('2019-04-26 10:00:00+0000', tz='UTC'), -11445.39999999851)
# (Timestamp('2019-04-30 10:00:00+0000', tz='UTC'), -161258.65000000037)
# (Timestamp('2019-05-02 10:00:00+0000', tz='UTC'), 66130.83939999901)
# (Timestamp('2019-05-03 10:00:00+0000', tz='UTC'), 103110.14999999851)
# (Timestamp('2019-05-06 10:00:00+0000', tz='UTC'), -111356.44999999739)
# (Timestamp('2019-05-07 10:00:00+0000', tz='UTC'), -90549.05000000075)
# (Timestamp('2019-05-08 10:00:00+0000', tz='UTC'), -347044.9000000004)
# (Timestamp('2019-05-09 10:00:00+0000', tz='UTC'), 60118.40000000037)
# (Timestamp('2019-05-10 10:00:00+0000', tz='UTC'), 10876.099999997765)
# (Timestamp('2019-05-13 10:00:00+0000', tz='UTC'), -384727.09999999776)
# (Timestamp('2019-05-14 10:00:00+0000', tz='UTC'), 184368.04999999888)
# (Timestamp('2019-05-15 10:00:00+0000', tz='UTC'), -142402.44999999925)
# (Timestamp('2019-05-16 10:00:00+0000', tz='UTC'), 131226.6499999985)
# (Timestamp('2019-05-17 10:00:00+0000', tz='UTC'), 36160.25000000186)
# (Timestamp('2019-05-20 10:00:00+0000', tz='UTC'), 370046.8499999996)
# (Timestamp('2019-05-21 10:00:00+0000', tz='UTC'), -23669.950000001118)
# (Timestamp('2019-05-22 10:00:00+0000', tz='UTC'), 133027.70000000298)
# (Timestamp('2019-05-23 10:00:00+0000', tz='UTC'), 722.3039999976754)
# (Timestamp('2019-05-24 10:00:00+0000', tz='UTC'), 225773.4960000012)
# (Timestamp('2019-05-27 10:00:00+0000', tz='UTC'), 24773.799999998882)
# (Timestamp('2019-05-28 10:00:00+0000', tz='UTC'), -101728.59999999963)
# (Timestamp('2019-05-29 10:00:00+0000', tz='UTC'), -97413.94999999925)
# (Timestamp('2019-05-30 10:00:00+0000', tz='UTC'), 73865.99999999814)
# (Timestamp('2019-05-31 10:00:00+0000', tz='UTC'), -110740.64999999851)
# (Timestamp('2019-06-03 10:00:00+0000', tz='UTC'), -43126.9862750005)
# (Timestamp('2019-06-04 10:00:00+0000', tz='UTC'), 20704.400000000373)
# (Timestamp('2019-06-06 10:00:00+0000', tz='UTC'), -167008.48599999957)
# (Timestamp('2019-06-07 10:00:00+0000', tz='UTC'), -74755.21399999969)
# (Timestamp('2019-06-10 10:00:00+0000', tz='UTC'), -324400.9500000011)
# (Timestamp('2019-06-11 10:00:00+0000', tz='UTC'), 36538.199999999255)
# (Timestamp('2019-06-12 10:00:00+0000', tz='UTC'), -45924.54999999888)
# (Timestamp('2019-06-13 10:00:00+0000', tz='UTC'), -33188.69999999739)
# (Timestamp('2019-06-14 10:00:00+0000', tz='UTC'), -248322.95000000112)
# (Timestamp('2019-06-17 10:00:00+0000', tz='UTC'), -209633.50000000186)
# (Timestamp('2019-06-18 10:00:00+0000', tz='UTC'), -55993.99999999814)
# (Timestamp('2019-06-19 10:00:00+0000', tz='UTC'), -190728.59999999963)
# (Timestamp('2019-06-20 10:00:00+0000', tz='UTC'), 160591.79999999888)
# (Timestamp('2019-06-24 10:00:00+0000', tz='UTC'), -36025.25)
# (Timestamp('2019-06-25 10:00:00+0000', tz='UTC'), 61015.95000000112)
# (Timestamp('2019-06-26 10:00:00+0000', tz='UTC'), 17402.499999998137)
# (Timestamp('2019-06-27 10:00:00+0000', tz='UTC'), -8664.299999998882)
# (Timestamp('2019-06-28 10:00:00+0000', tz='UTC'), -61906.10000000149)
# (Timestamp('2019-07-01 10:00:00+0000', tz='UTC'), 160473.35206099972)
# (Timestamp('2019-07-02 10:00:00+0000', tz='UTC'), -59689.12799999863)
# (Timestamp('2019-07-03 10:00:00+0000', tz='UTC'), 66193.99999999814)
# (Timestamp('2019-07-04 10:00:00+0000', tz='UTC'), 48627.85000000149)
# (Timestamp('2019-07-05 10:00:00+0000', tz='UTC'), -183180.69999999925)
# (Timestamp('2019-07-08 10:00:00+0000', tz='UTC'), -135246.15000000037)
# (Timestamp('2019-07-09 10:00:00+0000', tz='UTC'), 125697.44999999925)
# (Timestamp('2019-07-10 10:00:00+0000', tz='UTC'), -137980.75)
# (Timestamp('2019-07-11 10:00:00+0000', tz='UTC'), -19133.0)
# (Timestamp('2019-07-12 10:00:00+0000', tz='UTC'), 48918.800000000745)
# (Timestamp('2019-07-15 10:00:00+0000', tz='UTC'), 4810.89999999851)
# (Timestamp('2019-07-16 10:00:00+0000', tz='UTC'), 30179.450000001118)
# (Timestamp('2019-07-17 10:00:00+0000', tz='UTC'), 7892.8499999996275)
# (Timestamp('2019-07-18 10:00:00+0000', tz='UTC'), -21742.650000000373)
# (Timestamp('2019-07-19 10:00:00+0000', tz='UTC'), 18093.900000002235)
# (Timestamp('2019-07-22 10:00:00+0000', tz='UTC'), -233257.80000000075)
# (Timestamp('2019-07-23 10:00:00+0000', tz='UTC'), -1100.3499999996275)
# (Timestamp('2019-07-24 10:00:00+0000', tz='UTC'), -84534.60000000149)
# (Timestamp('2019-07-25 10:00:00+0000', tz='UTC'), -25696.400000000373)
# (Timestamp('2019-07-26 10:00:00+0000', tz='UTC'), 89269.5)
# (Timestamp('2019-07-29 10:00:00+0000', tz='UTC'), -77124.69999999925)
# (Timestamp('2019-07-30 10:00:00+0000', tz='UTC'), -242894.05000000075)
# (Timestamp('2019-07-31 10:00:00+0000', tz='UTC'), 104383.70000000112)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(3, 1, sharex=True, figsize=[16, 9])
perf.portfolio_value.plot(ax=ax[0])
ax[0].set_ylabel('portfolio value in rupees')

#asset
# Out:
# Text(0, 0.5, 'portfolio value in rupees')

# %%
# mark transactions
perf_trans = perf.loc[[t != [] for t in perf.transactions]]
buys = perf_trans.loc[[t[0]['amount'] > 0 for t in perf_trans.transactions]]
sells = perf_trans.loc[[t[0]['amount'] < 0 for t in perf_trans.transactions]]

# %%
perf_trans
# Out:
#                            algo_volatility  algorithm_period_return     alpha  \
# 2019-04-01 10:00:00+00:00         0.000769                -0.000506 -0.001126
# 2019-05-02 10:00:00+00:00         0.083940                -0.002958 -0.001878
# 2019-06-03 10:00:00+00:00         0.131628                -0.012827 -0.016194
# 2019-07-01 10:00:00+00:00         0.146780                -0.112809 -0.179341
#
#                            benchmark_period_return  benchmark_volatility  \
# 2019-04-01 10:00:00+00:00                 0.045635              0.194995
# 2019-05-02 10:00:00+00:00                 0.074222              0.180981
# 2019-06-03 10:00:00+00:00                 0.012944              0.176755
# 2019-07-01 10:00:00+00:00                 0.088224              0.171562
#
#                                beta  capital_used   ending_cash  \
# 2019-04-01 10:00:00+00:00 -0.000353 -1.001431e+07 -14307.647900
# 2019-05-02 10:00:00+00:00 -0.002906  7.186024e+04  57552.591500
# 2019-06-03 10:00:00+00:00  0.084369  1.077736e+04  68329.955225
# 2019-07-01 10:00:00+00:00  0.075052  2.234012e+04  90670.079286
#
#                            ending_exposure  ending_value  \
# 2019-04-01 10:00:00+00:00     1.000925e+07  1.000925e+07
# 2019-05-02 10:00:00+00:00     9.912870e+06  9.912870e+06
# 2019-06-03 10:00:00+00:00     9.803403e+06  9.803403e+06
# 2019-07-01 10:00:00+00:00     8.781236e+06  8.781236e+06
#
#                                    ...            short_exposure  short_value  \
# 2019-04-01 10:00:00+00:00          ...                       0.0          0.0
# 2019-05-02 10:00:00+00:00          ...                       0.0          0.0
# 2019-06-03 10:00:00+00:00          ...                       0.0          0.0
# 2019-07-01 10:00:00+00:00          ...                       0.0          0.0
#
#                            shorts_count   sortino  starting_cash  \
# 2019-04-01 10:00:00+00:00             0 -1.520502   1.000000e+07
# 2019-05-02 10:00:00+00:00             0 -0.039675  -1.430765e+04
# 2019-06-03 10:00:00+00:00             0 -0.137414   5.755259e+04
# 2019-07-01 10:00:00+00:00             0 -1.474881   6.832996e+04
#
#                            starting_exposure  starting_value  trading_days  \
# 2019-04-01 10:00:00+00:00               0.00            0.00           109
# 2019-05-02 10:00:00+00:00         9918599.80      9918599.80           128
# 2019-06-03 10:00:00+00:00         9857307.05      9857307.05           150
# 2019-07-01 10:00:00+00:00         8643102.95      8643102.95           168
#
#                                                                 transactions  \
# 2019-04-01 10:00:00+00:00  [{'amount': 865, 'dt': 2019-04-01 10:00:00+00:...
# 2019-05-02 10:00:00+00:00  [{'amount': 1896, 'dt': 2019-05-02 10:00:00+00...
# 2019-06-03 10:00:00+00:00  [{'amount': -1896, 'dt': 2019-06-03 10:00:00+0...
# 2019-07-01 10:00:00+00:00  [{'amount': -117, 'dt': 2019-07-01 10:00:00+00...
#
#                           treasury_period_return
# 2019-04-01 10:00:00+00:00                    0.0
# 2019-05-02 10:00:00+00:00                    0.0
# 2019-06-03 10:00:00+00:00                    0.0
# 2019-07-01 10:00:00+00:00                    0.0
#
# [4 rows x 37 columns]

# %%
sells
# Out:
#                            algo_volatility  algorithm_period_return     alpha  \
# 2019-06-03 10:00:00+00:00         0.131628                -0.012827 -0.016194
# 2019-07-01 10:00:00+00:00         0.146780                -0.112809 -0.179341
#
#                            benchmark_period_return  benchmark_volatility  \
# 2019-06-03 10:00:00+00:00                 0.012944              0.176755
# 2019-07-01 10:00:00+00:00                 0.088224              0.171562
#
#                                beta  capital_used   ending_cash  \
# 2019-06-03 10:00:00+00:00  0.084369  10777.363725  68329.955225
# 2019-07-01 10:00:00+00:00  0.075052  22340.124061  90670.079286
#
#                            ending_exposure  ending_value  \
# 2019-06-03 10:00:00+00:00      9803402.700   9803402.700
# 2019-07-01 10:00:00+00:00      8781236.178   8781236.178
#
#                                    ...            short_exposure  short_value  \
# 2019-06-03 10:00:00+00:00          ...                       0.0          0.0
# 2019-07-01 10:00:00+00:00          ...                       0.0          0.0
#
#                            shorts_count   sortino  starting_cash  \
# 2019-06-03 10:00:00+00:00             0 -0.137414   57552.591500
# 2019-07-01 10:00:00+00:00             0 -1.474881   68329.955225
#
#                            starting_exposure  starting_value  trading_days  \
# 2019-06-03 10:00:00+00:00         9857307.05      9857307.05           150
# 2019-07-01 10:00:00+00:00         8643102.95      8643102.95           168
#
#                                                                 transactions  \
# 2019-06-03 10:00:00+00:00  [{'amount': -1896, 'dt': 2019-06-03 10:00:00+0...
# 2019-07-01 10:00:00+00:00  [{'amount': -117, 'dt': 2019-07-01 10:00:00+00...
#
#                           treasury_period_return
# 2019-06-03 10:00:00+00:00                    0.0
# 2019-07-01 10:00:00+00:00                    0.0
#
# [2 rows x 37 columns]
