# %%
# %load_ext zipline

# %%
# %zipline ingest --help

from zipline.data import bundles
import os
import pandas as pd
from zipline.data.bundles import register, load
from zipline.data.bundles.csvdir import csvdir_equities
from zipline.data.bundles.yahoo import yahoo_stock_data
from zipline.data.data_portal import DataPortal
from zipline import run_algorithm
from zipline.api import schedule_function
from zipline.pipeline.data import Column
from zipline.pipeline.pipeline import Pipeline

from zipline.pipeline.data import USEquityPricing
from zipline.pipeline.engine import SimplePipelineEngine
from zipline.pipeline.loaders import USEquityPricingLoader
from trading_calendars.trading_calendar import TradingCalendar
from trading_calendars import get_calendar
import itertools
from zipline.pipeline.filters import StaticAssets

# Import visualization
import matplotlib.pyplot as plt
# Out:
# Usage: %zipline [OPTIONS]
#
#   Run a backtest for the given algorithm.
#
# Options:
#   -f, --algofile FILENAME         The file that contains the algorithm to run.
#   -t, --algotext TEXT             The algorithm script to run.
#   -D, --define TEXT               Define a name to be bound in the namespace
#                                   before executing the algotext. For example
#                                   '-Dname=value'. The value may be any python
#                                   expression. These are evaluated in order so
#                                   they may refer to previously defined names.
#   --data-frequency [daily|minute]
#                                   The data frequency of the simulation.
#                                   [default: daily]
#   --capital-base FLOAT            The starting capital for the simulation.
#                                   [default: 10000000.0]
#   -b, --bundle BUNDLE-NAME        The data bundle to use for the simulation.
#                                   [default: quandl]
#   --bundle-timestamp TIMESTAMP    The date to lookup data on or before.
#                                   [default: <current-time>]
#   -s, --start DATE                The start date of the simulation.
#   -e, --end DATE                  The end date of the simulation.
#   -o, --output FILENAME           The location to write the perf data. If this
#                                   is '-' the perf will be written to stdout.
#                                   [default: -]
#   --trading-calendar TRADING-CALENDAR
#                                   The calendar you want to use e.g. LSE. NYSE
#                                   is the default.
#   --print-algo / --no-print-algo  Print the algorithm to stdout.
#   --metrics-set TEXT              The metrics set to use. New metrics sets may
#                                   be registered in your extension.py.
#   --blotter TEXT                  The blotter to use.  [default: default]
#   --local-namespace / --no-local-namespace
#                                   Should the algorithm methods be resolved in
#                                   the local namespace.
#   --help                          Show this message and exit.

# %%
# result = run_algorithm(
#     start=start_session, 
#     end=end_session, 
#     initialize=initialize, 
#     analyze=analyze, 
#     handle_data=handle_data, 
#     capital_base=100000, 
#     data_frequency = 'daily', 
#     bundle='yahoo-bundle',
   
# )

# %%
import pandas as pd
perf = pd.read_pickle('nse_20162019_weekly.pickle') # read in perf DataFrame

# %%
# Import visualization
import matplotlib.pyplot as plt
def analyze(perf):
    fig = plt.figure(figsize=(12, 8))
    
    # First chart
    ax = fig.add_subplot(311)
    ax.set_title('Strategy Results')
    ax.semilogy(perf['portfolio_value'], linestyle='-', 
                label='Equity Curve', linewidth=3.0)
    ax.legend()
    ax.grid(False)
    
    # Second chart
    ax = fig.add_subplot(312)
    ax.plot(perf['gross_leverage'], 
            label='Exposure', linestyle='-', linewidth=1.0)
    ax.legend()
    ax.grid(True)

    # Third chart
    ax = fig.add_subplot(313)
    ax.plot(perf['returns'], label='Returns', linestyle='-.', linewidth=1.0)
    ax.legend()
    ax.grid(True)

# %%
analyze(perf)

# %%
perf.to_csv("results.csv")

# %%
import pandas as pd
import pyfolio as pf

# %%
results = pd.read_pickle('nse_20162019_weekly.pickle')
returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(results)

# %%
pf.plot_drawdown_periods(returns, top=5).set_xlabel('Date')
# Out:
# /opt/anaconda3/envs/env_zipline/lib/python3.5/site-packages/numpy/core/fromnumeric.py:52: FutureWarning: 'argmin' is deprecated. Use 'idxmin' instead. The behavior of 'argmin' will be corrected to return the positional minimum in the future. Use 'series.values.argmin' to get the position of the minimum now.
#   return getattr(obj, method)(*args, **kwds)
# Text(0.5, 0, 'Date')

# %%
pf.create_full_tear_sheet(returns, positions=positions, transactions=transactions, round_trips=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2008-01-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2015-12-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>93</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>71.3%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>6590.9%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>66.9%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.09</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.96</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.86</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-74.2%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.36</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.21</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>8.88</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>194.23</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.11</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-8.1%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>1.86</td>
#     </tr>
#     <tr>
#       <th>Daily turnover</th>
#       <td>2.6%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>74.21</td>
#       <td>2008-02-05</td>
#       <td>2009-03-12</td>
#       <td>2009-11-24</td>
#       <td>471</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>41.78</td>
#       <td>2015-04-07</td>
#       <td>2015-04-28</td>
#       <td>2015-07-08</td>
#       <td>67</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>39.50</td>
#       <td>2015-10-08</td>
#       <td>2015-12-30</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>35.49</td>
#       <td>2014-11-10</td>
#       <td>2014-12-18</td>
#       <td>2015-02-18</td>
#       <td>73</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>33.14</td>
#       <td>2013-01-04</td>
#       <td>2013-10-14</td>
#       <td>2014-01-03</td>
#       <td>261</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Lehman</th>
#       <td>-0.15%</td>
#       <td>-5.45%</td>
#       <td>5.14%</td>
#     </tr>
#     <tr>
#       <th>US downgrade/European Debt Crisis</th>
#       <td>0.16%</td>
#       <td>-3.47%</td>
#       <td>4.27%</td>
#     </tr>
#     <tr>
#       <th>Fukushima</th>
#       <td>0.81%</td>
#       <td>-1.70%</td>
#       <td>2.80%</td>
#     </tr>
#     <tr>
#       <th>EZB IR Event</th>
#       <td>0.33%</td>
#       <td>-1.76%</td>
#       <td>3.87%</td>
#     </tr>
#     <tr>
#       <th>Mar08</th>
#       <td>-0.87%</td>
#       <td>-6.81%</td>
#       <td>6.07%</td>
#     </tr>
#     <tr>
#       <th>Sept08</th>
#       <td>-0.47%</td>
#       <td>-5.45%</td>
#       <td>5.14%</td>
#     </tr>
#     <tr>
#       <th>2009Q1</th>
#       <td>-0.76%</td>
#       <td>-6.09%</td>
#       <td>5.56%</td>
#     </tr>
#     <tr>
#       <th>2009Q2</th>
#       <td>2.13%</td>
#       <td>-45.20%</td>
#       <td>91.35%</td>
#     </tr>
#     <tr>
#       <th>Flash Crash</th>
#       <td>0.26%</td>
#       <td>-3.56%</td>
#       <td>4.25%</td>
#     </tr>
#     <tr>
#       <th>Apr14</th>
#       <td>1.23%</td>
#       <td>-5.04%</td>
#       <td>13.32%</td>
#     </tr>
#     <tr>
#       <th>Oct14</th>
#       <td>0.60%</td>
#       <td>-15.88%</td>
#       <td>9.61%</td>
#     </tr>
#     <tr>
#       <th>Fall2015</th>
#       <td>0.58%</td>
#       <td>-12.66%</td>
#       <td>12.99%</td>
#     </tr>
#     <tr>
#       <th>GFC Crash</th>
#       <td>-0.07%</td>
#       <td>-8.46%</td>
#       <td>91.35%</td>
#     </tr>
#     <tr>
#       <th>Recovery</th>
#       <td>0.37%</td>
#       <td>-45.20%</td>
#       <td>91.35%</td>
#     </tr>
#     <tr>
#       <th>New Normal</th>
#       <td>0.46%</td>
#       <td>-21.71%</td>
#       <td>82.42%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 long positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AVANTIFEED.NS</th>
#       <td>218.38%</td>
#     </tr>
#     <tr>
#       <th>DEEPAKNTR.NS</th>
#       <td>59.33%</td>
#     </tr>
#     <tr>
#       <th>SOLARINDS.NS</th>
#       <td>58.98%</td>
#     </tr>
#     <tr>
#       <th>WELSPUNIND.NS</th>
#       <td>46.12%</td>
#     </tr>
#     <tr>
#       <th>ITDCEM.NS</th>
#       <td>45.13%</td>
#     </tr>
#     <tr>
#       <th>SUDARSCHEM.NS</th>
#       <td>38.43%</td>
#     </tr>
#     <tr>
#       <th>AEGISCHEM.NS</th>
#       <td>23.71%</td>
#     </tr>
#     <tr>
#       <th>MINDAIND.NS</th>
#       <td>20.79%</td>
#     </tr>
#     <tr>
#       <th>IBULISL.NS</th>
#       <td>19.74%</td>
#     </tr>
#     <tr>
#       <th>MINDACORP.NS</th>
#       <td>18.47%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 short positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AVANTIFEED.NS</th>
#       <td>-147.02%</td>
#     </tr>
#     <tr>
#       <th>IBULISL.NS</th>
#       <td>-90.53%</td>
#     </tr>
#     <tr>
#       <th>SUDARSCHEM.NS</th>
#       <td>-86.45%</td>
#     </tr>
#     <tr>
#       <th>DEEPAKNTR.NS</th>
#       <td>-74.14%</td>
#     </tr>
#     <tr>
#       <th>ITDCEM.NS</th>
#       <td>-61.75%</td>
#     </tr>
#     <tr>
#       <th>MINDAIND.NS</th>
#       <td>-48.30%</td>
#     </tr>
#     <tr>
#       <th>RUPA.NS</th>
#       <td>-14.00%</td>
#     </tr>
#     <tr>
#       <th>WELSPUNIND.NS</th>
#       <td>-12.35%</td>
#     </tr>
#     <tr>
#       <th>VMART.NS</th>
#       <td>-7.26%</td>
#     </tr>
#     <tr>
#       <th>TRIDENT.NS</th>
#       <td>-5.65%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AVANTIFEED.NS</th>
#       <td>218.38%</td>
#     </tr>
#     <tr>
#       <th>IBULISL.NS</th>
#       <td>90.53%</td>
#     </tr>
#     <tr>
#       <th>SUDARSCHEM.NS</th>
#       <td>86.45%</td>
#     </tr>
#     <tr>
#       <th>DEEPAKNTR.NS</th>
#       <td>74.14%</td>
#     </tr>
#     <tr>
#       <th>ITDCEM.NS</th>
#       <td>61.75%</td>
#     </tr>
#     <tr>
#       <th>SOLARINDS.NS</th>
#       <td>58.98%</td>
#     </tr>
#     <tr>
#       <th>MINDAIND.NS</th>
#       <td>48.30%</td>
#     </tr>
#     <tr>
#       <th>WELSPUNIND.NS</th>
#       <td>46.12%</td>
#     </tr>
#     <tr>
#       <th>AEGISCHEM.NS</th>
#       <td>23.71%</td>
#     </tr>
#     <tr>
#       <th>MINDACORP.NS</th>
#       <td>18.47%</td>
#     </tr>
#   </tbody>
# </table>
# /opt/anaconda3/envs/env_zipline/lib/python3.5/site-packages/pyfolio/round_trips.py:80: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   .agg(stats_dict)
# /opt/anaconda3/envs/env_zipline/lib/python3.5/site-packages/pyfolio/round_trips.py:83: FutureWarning: Using 'rename_axis' to alter labels is deprecated. Use '.rename' instead
#   axis='columns'))
# /opt/anaconda3/envs/env_zipline/lib/python3.5/site-packages/pyfolio/round_trips.py:86: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   .agg(stats_dict)
# /opt/anaconda3/envs/env_zipline/lib/python3.5/site-packages/pyfolio/round_trips.py:90: FutureWarning: Using 'rename_axis' to alter labels is deprecated. Use '.rename' instead
#   axis='columns'))
# /opt/anaconda3/envs/env_zipline/lib/python3.5/site-packages/pyfolio/round_trips.py:379: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#
</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Symbol stats</th>
#       <th>COX&amp;KINGS.NS</th>
#       <th>ASTRAL.NS</th>
#       <th>UFLEX.NS</th>
#       <th>BBTC.NS</th>
#       <th>SHREECEM.NS</th>
#       <th>DHFL.NS</th>
#       <th>MANAPPURAM.NS</th>
#       <th>ULTRACEMCO.NS</th>
#       <th>TTKPRESTIG.NS</th>
#       <th>CENTURYPLY.NS</th>
#       <th>LUPIN.NS</th>
#       <th>VGUARD.NS</th>
#       <th>MOTILALOFS.NS</th>
#       <th>TATAELXSI.NS</th>
#       <th>RELAXO.NS</th>
#       <th>JYOTHYLAB.NS</th>
#       <th>RELINFRA.NS</th>
#       <th>IRB.NS</th>
#       <th>SUZLON.NS</th>
#       <th>ZENSARTECH.NS</th>
#       <th>SHILPAMED.NS</th>
#       <th>MAGMA.NS</th>
#       <th>TATACOFFEE.NS</th>
#       <th>REPCOHOME.NS</th>
#       <th>MARUTI.NS</th>
#       <th>NCC.NS</th>
#       <th>TATAGLOBAL.NS</th>
#       <th>BEML.NS</th>
#       <th>BLUEDART.NS</th>
#       <th>VAKRANGEE.NS</th>
#       <th>SUVEN.NS</th>
#       <th>JSWSTEEL.NS</th>
#       <th>RENUKA.NS</th>
#       <th>COROMANDEL.NS</th>
#       <th>KOLTEPATIL.NS</th>
#       <th>NBCC.NS</th>
#       <th>CONCOR.NS</th>
#       <th>BIRLACORPN.NS</th>
#       <th>TATAMTRDVR.NS</th>
#       <th>HEXAWARE.NS</th>
#       <th>GHCL.NS</th>
#       <th>JPASSOCIAT.NS</th>
#       <th>OFSS.NS</th>
#       <th>MINDTREE.NS</th>
#       <th>WABCOINDIA.NS</th>
#       <th>AEGISCHEM.NS</th>
#       <th>GULFOILLUB.NS</th>
#       <th>MINDAIND.NS</th>
#       <th>SONATSOFTW.NS</th>
#       <th>JKTYRE.NS</th>
#       <th>HSCL.NS</th>
#       <th>GODREJIND.NS</th>
#       <th>VOLTAS.NS</th>
#       <th>BEL.NS</th>
#       <th>UBL.NS</th>
#       <th>KEC.NS</th>
#       <th>KAJARIACER.NS</th>
#       <th>RALLIS.NS</th>
#       <th>RCF.NS</th>
#       <th>RADICO.NS</th>
#       <th>ECLERX.NS</th>
#       <th>TATAMOTORS.NS</th>
#       <th>ASTRAZEN.NS</th>
#       <th>ASIANPAINT.NS</th>
#       <th>SREINFRA.NS</th>
#       <th>TV18BRDCST.NS</th>
#       <th>AMARAJABAT.NS</th>
#       <th>AJANTPHARM.NS</th>
#       <th>JINDALSTEL.NS</th>
#       <th>DCMSHRIRAM.NS</th>
#       <th>TAKE.NS</th>
#       <th>ENGINERSIN.NS</th>
#       <th>WOCKPHARMA.NS</th>
#       <th>NFL.NS</th>
#       <th>GAYAPROJ.NS</th>
#       <th>CYIENT.NS</th>
#       <th>AVANTIFEED.NS</th>
#       <th>VEDL.NS</th>
#       <th>SUPREMEIND.NS</th>
#       <th>IPCALAB.NS</th>
#       <th>CENTRALBK.NS</th>
#       <th>DLF.NS</th>
#       <th>CEATLTD.NS</th>
#       <th>SYMPHONY.NS</th>
#       <th>JAICORPLTD.NS</th>
#       <th>DCAL.NS</th>
#       <th>KSCL.NS</th>
#       <th>RAJESHEXPO.NS</th>
#       <th>INDIANB.NS</th>
#       <th>RUPA.NS</th>
#       <th>MUTHOOTFIN.NS</th>
#       <th>J&amp;KBANK.NS</th>
#       <th>ELGIEQUIP.NS</th>
#       <th>CHOLAFIN.NS</th>
#       <th>WHIRLPOOL.NS</th>
#       <th>GRANULES.NS</th>
#       <th>BOSCHLTD.NS</th>
#       <th>MAHINDCIE.NS</th>
#       <th>SRF.NS</th>
#       <th>SUNTECK.NS</th>
#       <th>ITDCEM.NS</th>
#       <th>CAPLIPOINT.NS</th>
#       <th>BLISSGVS.NS</th>
#       <th>IFBIND.NS</th>
#       <th>CUB.NS</th>
#       <th>VSTIND.NS</th>
#       <th>BRITANNIA.NS</th>
#       <th>RKFORGE.NS</th>
#       <th>BAJFINANCE.NS</th>
#       <th>PHILIPCARB.NS</th>
#       <th>APLLTD.NS</th>
#       <th>DEEPAKNTR.NS</th>
#       <th>CANBK.NS</th>
#       <th>KPRMILL.NS</th>
#       <th>THOMASCOOK.NS</th>
#       <th>VIPIND.NS</th>
#       <th>KALPATPOWR.NS</th>
#       <th>JUSTDIAL.NS</th>
#       <th>L&amp;TFH.NS</th>
#       <th>IBULISL.NS</th>
#       <th>MRF.NS</th>
#       <th>JETAIRWAYS.NS</th>
#       <th>SPARC.NS</th>
#       <th>GMDCLTD.NS</th>
#       <th>KRBL.NS</th>
#       <th>VINATIORGA.NS</th>
#       <th>WELSPUNIND.NS</th>
#       <th>SHRIRAMCIT.NS</th>
#       <th>VTL.NS</th>
#       <th>HEIDELBERG.NS</th>
#       <th>CRISIL.NS</th>
#       <th>EXCELCROP.NS</th>
#       <th>WELCORP.NS</th>
#       <th>CERA.NS</th>
#       <th>SOUTHBANK.NS</th>
#       <th>HERITGFOOD.NS</th>
#       <th>FEDERALBNK.NS</th>
#       <th>ABFRL.NS</th>
#       <th>FINPIPE.NS</th>
#       <th>VMART.NS</th>
#       <th>MAHSCOOTER.NS</th>
#       <th>PCJEWELLER.NS</th>
#       <th>NBVENTURES.NS</th>
#       <th>KTKBANK.NS</th>
#       <th>SRTRANSFIN.NS</th>
#       <th>PRAJIND.NS</th>
#       <th>STRTECH.NS</th>
#       <th>CANFINHOME.NS</th>
#       <th>STAR.NS</th>
#       <th>SUDARSCHEM.NS</th>
#       <th>SUPRAJIT.NS</th>
#       <th>GUJALKALI.NS</th>
#       <th>ATUL.NS</th>
#       <th>JAMNAAUTO.NS</th>
#       <th>SOLARINDS.NS</th>
#       <th>KARURVYSYA.NS</th>
#       <th>IFCI.NS</th>
#       <th>FSL.NS</th>
#       <th>RAYMOND.NS</th>
#       <th>RECLTD.NS</th>
#       <th>NATCOPHARM.NS</th>
#       <th>MINDACORP.NS</th>
#       <th>BERGEPAINT.NS</th>
#       <th>AUROPHARMA.NS</th>
#       <th>LICHSGFIN.NS</th>
#       <th>KANSAINER.NS</th>
#       <th>NETWORK18.NS</th>
#       <th>SHOPERSTOP.NS</th>
#       <th>SUNPHARMA.NS</th>
#       <th>NILKAMAL.NS</th>
#       <th>TRIDENT.NS</th>
#       <td>-1.42%</td>
#       <td>-0.82%</td>
#       <td>0.29%</td>
#       <td>3.88%</td>
#       <td>-8.55%</td>
#       <td>0.02%</td>
#       <td>0.66%</td>
#       <td>0.07%</td>
#       <td>-0.11%</td>
#       <td>0.74%</td>
#       <td>1.35%</td>
#       <td>0.34%</td>
#       <td>-0.11%</td>
#       <td>0.87%</td>
#       <td>1.36%</td>
#       <td>-0.18%</td>
#       <td>-0.06%</td>
#       <td>0.14%</td>
#       <td>-0.04%</td>
#       <td>0.30%</td>
#       <td>-14.99%</td>
#       <td>-0.00%</td>
#       <td>3.29%</td>
#       <td>-0.41%</td>
#       <td>2.17%</td>
#       <td>-0.08%</td>
#       <td>1.12%</td>
#       <td>0.67%</td>
#       <td>-1.12%</td>
#       <td>0.00%</td>
#       <td>-0.00%</td>
#       <td>0.78%</td>
#       <td>-0.35%</td>
#       <td>1.53%</td>
#       <td>-1.90%</td>
#       <td>-0.14%</td>
#       <td>0.80%</td>
#       <td>-0.00%</td>
#       <td>-0.12%</td>
#       <td>-0.72%</td>
#       <td>-0.40%<
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Profitability (PnL / PnL total) per name</th>
#       <th></th>
#     </tr>
#     <tr>
#       <th>symbol</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AVANTIFEED.NS</th>
#       <td>58.77%</td>
#     </tr>
#     <tr>
#       <th>GAYAPROJ.NS</th>
#       <td>9.80%</td>
#     </tr>
#     <tr>
#       <th>RAJESHEXPO.NS</th>
#       <td>9.18%</td>
#     </tr>
#     <tr>
#       <th>WELSPUNIND.NS</th>
#       <td>6.35%</td>
#     </tr>
#     <tr>
#       <th>TRIDENT.NS</th>
#       <td>5.20%</td>
#     </tr>
#     <tr>
#       <th>DEEPAKNTR.NS</th>
#       <td>4.73%</td>
#     </tr>
#     <tr>
#       <th>NBCC.NS</th>
#       <td>3.46%</td>
#     </tr>
#     <tr>
#       <th>MINDACORP.NS</th>
#       <td>2.19%</td>
#     </tr>
#     <tr>
#       <th>AEGISCHEM.NS</th>
#       <td>2.09%</td>
#     </tr>
#     <tr>
#       <th>IFBIND.NS</th>
#       <td>2.02%</td>
#     </tr>
#     <tr>
#       <th>CAPLIPOINT.NS</th>
#       <td>1.86%</td>
#     </tr>
#     <tr>
#       <th>ABFRL.NS</th>
#       <td>1.64%</td>
#     </tr>
#     <tr>
#       <th>CHENNPETRO.NS</th>
#       <td>1.54%</td>
#     </tr>
#     <tr>
#       <th>CCL.NS</th>
#       <td>1.43%</td>
#     </tr>
#     <tr>
#       <th>KEC.NS</th>
#       <td>1.28%</td>
#     </tr>
#     <tr>
#       <th>CENTURYPLY.NS</th>
#       <td>1.24%</td>
#     </tr>
#     <tr>
#       <th>SUVEN.NS</th>
#       <td>0.98%</td>
#     </tr>
#     <tr>
#       <th>RKFORGE.NS</th>
#       <td>0.96%</td>
#     </tr>
#     <tr>
#       <th>BEL.NS</th>
#       <td>0.95%</td>
#     </tr>
#     <tr>
#       <th>RUPA.NS</th>
#       <td>0.94%</td>
#     </tr>
#     <tr>
#       <th>NCC.NS</th>
#       <td>0.81%</td>
#     </tr>
#     <tr>
#       <th>KPRMILL.NS</th>
#       <td>0.80%</td>
#     </tr>
#     <tr>
#       <th>JKLAKSHMI.NS</th>
#       <td>0.78%</td>
#     </tr>
#     <tr>
#       <th>PCJEWELLER.NS</th>
#       <td>0.77%</td>
#     </tr>
#     <tr>
#       <th>AJANTPHARM.NS</th>
#       <td>0.72%</td>
#     </tr>
#     <tr>
#       <th>JAMNAAUTO.NS</th>
#       <td>0.71%</td>
#     </tr>
#     <tr>
#       <th>DCMSHRIRAM.NS</th>
#       <td>0.69%</td>
#     </tr>
#     <tr>
#       <th>PVR.NS</th>
#       <td>0.56%</td>
#     </tr>
#     <tr>
#       <th>NATCOPHARM.NS</th>
#       <td>0.54%</td>
#     </tr>
#     <tr>
#       <th>KNRCON.NS</th>
#       <td>0.53%</td>
#     </tr>
#     <tr>
#       <th>VAKRANGEE.NS</th>
#       <td>0.52%</td>
#     </tr>
#     <tr>
#       <th>SRF.NS</th>
#       <td>0.45%</td>
#     </tr>
#     <tr>
#       <th>MAHINDCIE.NS</th>
#       <td>0.41%</td>
#     </tr>
#     <tr>
#       <th>VGUARD.NS</th>
#       <td>0.39%</td>
#     </tr>
#     <tr>
#       <th>APLLTD.NS</th>
#       <td>0.36%</td>
#     </tr>
#     <tr>
#       <th>TTKPRESTIG.NS</th>
#       <td>0.35%</td>
#     </tr>
#     <tr>
#       <th>VTL.NS</th>
#       <td>0.34%</td>
#     </tr>
#     <tr>
#       <th>BBTC.NS</th>
#       <td>0.32%</td>
#     </tr>
#     <tr>
#       <th>AUROPHARMA.NS</th>
#       <td>0.32%</td>
#     </tr>
#     <tr>
#       <th>HERITGFOOD.NS</th>
#       <td>0.30%</td>
#     </tr>
#     <tr>
#       <th>KSCL.NS</th>
#       <td>0.29%</td>
#     </tr>
#     <tr>
#       <th>HEXAWARE.NS</th>
#       <td>0.29%</td>
#     </tr>
#     <tr>
#       <th>VINATIORGA.NS</th>
#       <td>0.27%</td>
#     </tr>
#     <tr>
#       <th>APOLLOTYRE.NS</th>
#       <td>0.27%</td>
#     </tr>
#     <tr>
#       <th>GRUH.NS</th>
#       <td>0.27%</td>
#     </tr>
#     <tr>
#       <th>TVSMOTOR.NS</th>
#       <td>0.26%</td>
#     </tr>
#     <tr>
#       <th>ATUL.NS</th>
#       <td>0.26%</td>
#     </tr>
#     <tr>
#       <th>GRANULES.NS</th>
#       <td>0.26%</td>
#     </tr>
#     <tr>
#       <th>BRITANNIA.NS</th>
#       <td>0.24%</td>
#     </tr>
#     <tr>
#       <th>IRB.NS</th>
#       <td>0.23%</td>
#     </tr>
#     <tr>
#       <th>KOLTEPATIL.NS</th>
#       <td>0.20%</td>
#     </tr>
#     <tr>
#       <th>PRSMJOHNSN.NS</th>
#       <td>0.20%</td>
#     </tr>
#     <tr>
#       <th>SUNPHARMA.NS</th>
#       <td>0.20%</td>
#     </tr>
#     <tr>
#       <th>FINPIPE.NS</th>
#       <td>0.20%</td>
#     </tr>
#     <tr>
#       <th>MOTHERSUMI.NS</th>
#       <td>0.19%</td>
#     </tr>
#     <tr>
#       <th>WHIRLPOOL.NS</th>
#       <td>0.17%</td>
#     </tr>
#     <tr>
#       <th>RELAXO.NS</th>
#       <td>0.16%</td>
#     </tr>
#     <tr>
#       <th>DELTACORP.NS</th>
#       <td>0.16%</td>
#     </tr>
#     <tr>
#       <th>REPCOHOME.NS</th>
#       <td>0.15%</td>
#     </tr>
#     <tr>
#       <th>VIPIND.NS</th>
#       <td>0.15%</td>
#     </tr>
#     <tr>
#       <th>BERGEPAINT.NS</th>
#       <td>0.15%</td>
#     </tr>
#     <tr>
#       <th>JUSTDIAL.NS</th>
#       <td>0.12%</td>
#     </tr>
#     <tr>
#       <th>SUPRAJIT.NS</th>
#       <td>0.12%</td>
#     </tr>
#     <tr>
#       <th>BAJFINANCE.NS</th>
#       <td>0.12%</td>
#     </tr>
#     <tr>
#       <th>JKCEMENT.NS</th>
#       <td>0.12%</td>
#     </tr>
#     <tr>
#       <th>LUPIN.NS</th>
#       <td>0.11%</td>
#     </tr>
#     <tr>
#       <th>VMART.NS</th>
#       <td>0.11%</td>
#     </tr>
#     <tr>
#       <th>VENKEYS.NS</th>
#       <td>0.11%</td>
#     </tr>
#     <tr>
#       <th>COX&amp;KINGS.NS</th>
#       <td>0.10%</td>
#     </tr>
#     <tr>
#       <th>TAKE.NS</th>
#       <td>0.10%</td>
#     </tr>
#     <tr>
#       <th>MONSANTO.NS</th>
#       <td>0.08%</td>
#     </tr>
#     <tr>
#       <th>ASTRAL.NS</th>
#       <td>0.07%</td>
#     </tr>
#     <tr>
#       <th>SOUTHBANK.NS</th>
#       <td>0.07%</td>
#     </tr>
#     <tr>
#       <th>SYMPHONY.NS</th>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <th>MUTHOOTFIN.NS</th>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <th>TATAELXSI.NS</th>
#       <td>0.06%</td>
#     </tr>
#     <tr>
#       <th>ZENSARTECH.NS</th>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <th>ZYDUSWELL.NS</th>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <th>J&amp;KBANK.NS</th>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <th>RAYMOND.NS</th>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <th>CEATLTD.NS</th>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <th>BLUEDART.NS</th>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <th>COROMANDEL.NS</th>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <th>NILKAMAL.NS</th>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <th>CONCOR.NS</th>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <th>ENGINERSIN.NS</th>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <th>CHOLAFIN.NS</th>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <th>FSL.NS</th>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <th>KANSAINER.NS</th>
#       <td>0.04%</td>
#     </tr>
#     <tr>
#       <th>MRF.NS</th>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <th>ECLERX.NS</th>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <th>JSWSTEEL.NS</th>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <th>INDOCO.NS</th>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <th>CYIENT.NS</th>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <th>STRTECH.NS</th>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <th>RALLIS.NS</th>
#       <td>0.03%</td>
#     </tr>
#     <tr>
#       <th>VOLTAS.NS</th>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <th>HAVELLS.NS</th>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <th>JINDALSTEL.NS</th>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <th>OFSS.NS</th>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <th>RECLTD.NS</th>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <th>SHREECEM.NS</th>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <th>KAJARIACER.NS</th>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <th>SHOPERSTOP.NS</th>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <th>JYOTHYLAB.NS</th>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <th>CRISIL.NS</th>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <th>TECHM.NS</th>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <th>ULTRACEMCO.NS</th>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <th>STAR.NS</th>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <th>MARUTI.NS</th>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <th>JPASSOCIAT.NS</th>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <th>BIRLACORPN.NS</th>
#       <td>0.02%</td>
#     </tr>
#     <tr>
#       <th>RENUKA.NS</th>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <th>HSCL.NS</th>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <th>WABCOINDIA.NS</th>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <th>SUPREMEIND.NS</th>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <th>TATAMOTORS.NS</th>

# %%
# Custom Time Series Analysis

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt, rc, ticker

# Format for book image
font = {'family' : 'eurostile',
        'weight' : 'normal',
        'size'   : 16}
rc('font', **font)

# Settings
calc_window = 126
year_length = 252

# Copy the columns we need
df = perf.copy().filter(items=['portfolio_value', 'gross_leverage'])

# Function for annualized return
def ann_ret(ts):
    return np.power((ts[-1] / ts[0]), (year_length/len(ts))) -1  

# Function for drawdown
def dd(ts):
    return np.min(ts / np.maximum.accumulate(ts)) - 1

# Get a rolling window
rolling_window = perf.portfolio_value.rolling(calc_window)

# Calculate rolling analytics
df['annualized'] = rolling_window.apply(ann_ret)
df['drawdown'] = rolling_window.apply(dd)

# Drop initial n/a values
df.dropna(inplace=True)

# Make a figure
fig = plt.figure(figsize=(12, 12))

# Make the base lower, just to make the graph easier to read
df['portfolio_value'] /= 100

# First chart
ax = fig.add_subplot(411)
ax.set_title('Strategy Results')
ax.plot(df['portfolio_value'], 
        linestyle='-', 
        color='black',
        label='Equity Curve', linewidth=3.0)

# Set log scale
ax.set_yscale('log') 

# Make the axis look nicer
ax.yaxis.set_ticks(np.arange(df['portfolio_value'].min(), df['portfolio_value'].max(), 500 ))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.0f'))

# Add legend and grid
ax.legend()
ax.grid(False)

# Second chart
ax = fig.add_subplot(412)
ax.plot(df['gross_leverage'], 
        label='Strategy exposure'.format(calc_window), 
        linestyle='-', 
        color='black',
        linewidth=1.0)

# Make the axis look nicer
ax.yaxis.set_ticks(np.arange(df['gross_leverage'].min(), df['gross_leverage'].max(), 0.02 ))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.2f'))

# Add legend and grid
ax.legend()
ax.grid(True)

# Third chart
ax = fig.add_subplot(413)
ax.plot(df['annualized'], 
        label='{} days annualized return'.format(calc_window), 
        linestyle='-', 
        color='black',
        linewidth=1.0)

# Make the axis look nicer
ax.yaxis.set_ticks(np.arange(df['annualized'].min(), df['annualized'].max(), 0.5 ))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.1f'))

# Add legend and grid
ax.legend()
ax.grid(True)

# Fourth chart
ax = fig.add_subplot(414)
ax.plot(df['drawdown'], 
        label='{} days max drawdown'.format(calc_window), 
        linestyle='-', 
        color='black',
        linewidth=1.0)

# Make the axis look nicer
ax.yaxis.set_ticks(np.arange(df['drawdown'].min(), df['drawdown'].max(), 0.1 ))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.1f'))

# Add legend and grid
ax.legend()
ax.grid(True)

# %%
df
# Out:
#                            portfolio_value  gross_leverage  annualized  \
# 2008-07-04 10:00:00+00:00     6.283125e+04        1.094388   -0.605223
# 2008-07-07 10:00:00+00:00     6.451460e+04        1.091925   -0.583787
# 2008-07-08 10:00:00+00:00     6.451489e+04        1.091925   -0.583783
# 2008-07-09 10:00:00+00:00     6.596306e+04        1.089907   -0.564887
# 2008-07-10 10:00:00+00:00     6.565899e+04        1.090323   -0.568890
# 2008-07-11 10:00:00+00:00     6.610748e+04        1.089710   -0.562980
# 2008-07-14 10:00:00+00:00     6.535874e+04        1.090738   -0.572824
# 2008-07-15 10:00:00+00:00     6.292321e+04        1.094250   -0.604067
# 2008-07-16 10:00:00+00:00     6.248633e+04        1.094909   -0.609546
# 2008-07-17 10:00:00+00:00     6.343789e+04        1.093485   -0.597563
# 2008-07-18 10:00:00+00:00     6.428710e+04        1.092250   -0.586717
# 2008-07-21 10:00:00+00:00     6.427690e+04        1.092265   -0.586848
# 2008-07-22 10:00:00+00:00     6.559625e+04        1.090409   -0.569713
# 2008-07-23 10:00:00+00:00     6.925591e+04        1.085632   -0.520362
# 2008-07-24 10:00:00+00:00     6.864445e+04        1.086395   -0.528794
# 2008-07-25 10:00:00+00:00     6.798050e+04        1.087238   -0.537865
# 2008-07-28 10:00:00+00:00     6.951617e+04        1.085311   -0.516750
# 2008-07-29 10:00:00+00:00     6.849987e+04        1.086577   -0.530777
# 2008-07-30 10:00:00+00:00     6.978196e+04        1.084986   -0.513048
