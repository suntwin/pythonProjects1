# %%
# %load_ext zipline
# Out:
# The zipline extension is already loaded. To reload it, use:
#   %reload_ext zipline

# %%
# %%zipline --bundle nse-bundle --start 2019-10-17 --end 2019-10-25
# from zipline.api import order_target, record, symbol
#
# def initialize(context):
#     context.i = 0
#     context.asset = symbol('VTL')
#
#
# def handle_data(context, data):
#     # Skip first 300 days to get full windows
#     context.i += 1
#     if context.i < 300:
#         return
#
#     # Compute averages
#     # data.history() has to be called with the same params
#     # from above and returns a pandas dataframe.
#     short_mavg = data.history(context.asset, 'price', bar_count=15, frequency="1d").mean()
#     long_mavg = data.history(context.asset, 'price', bar_count=29, frequency="1d").mean()
#
#     # Trading logic
#     if short_mavg > long_mavg:
#         print(context.asset)
#         # order_target orders as many shares as needed to
#         # achieve the desired number of shares.
#         order_target(context.asset, 100)
#     elif short_mavg < long_mavg:
#         order_target(context.asset, 0)
#
#     # Save values for later inspection
#     record(AAPL=data.current(context.asset, 'price'),
#            short_mavg=short_mavg,
#            long_mavg=long_mavg)
# Out:
#                            algo_volatility  algorithm_period_return  alpha  \
# 2019-10-17 20:00:00+00:00              NaN                      0.0    NaN
# 2019-10-18 20:00:00+00:00              0.0                      0.0    0.0
# 2019-10-21 20:00:00+00:00              0.0                      0.0    0.0
# 2019-10-22 20:00:00+00:00              0.0                      0.0    0.0
# 2019-10-23 20:00:00+00:00              0.0                      0.0    0.0
# 2019-10-24 20:00:00+00:00              0.0                      0.0    0.0
# 2019-10-25 20:00:00+00:00              0.0                      0.0    0.0
#
#                            benchmark_period_return  benchmark_volatility  \
# 2019-10-17 20:00:00+00:00                 0.002949                   NaN
# 2019-10-18 20:00:00+00:00                -0.001441              0.082237
# 2019-10-21 20:00:00+00:00                 0.005328              0.089989
# 2019-10-22 20:00:00+00:00                 0.002044              0.083699
# ...
