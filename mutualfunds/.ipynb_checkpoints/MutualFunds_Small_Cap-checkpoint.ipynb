# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from numpy.random import randn

# %%
df = pd.read_csv("C:\pythonProjects\mutualfunds\DataExtract\LinkFile\portfolio_holdings_Small&MidCap_051017.csv")
df.columns
# Out:
# Index([u'Equity', u'Sector', u'Qty', u'Value', u'%', u'Fund_Name',
#        u'Fund_Code', u'Time_Stamp'],
#       dtype='object')

# %%
df_equity_sector = DataFrame(df,columns=['Equity','Sector'])

# %%
df_equity_sector['stock_name'] = df_equity_sector.Equity

# %%
df_equity_sector_new = df_equity_sector.drop_duplicates()

# %%
number_of_stocks_per_fund = df['Fund_Name'].value_counts()

# %%
number_of_funds = df['Equity'].value_counts()

# %%
df_final = pd.concat([number_of_funds], axis=1)

# %%
df_final.rename(columns={'Equity':'stock_count'})
# Out:
#                  stock_count
# HDFC Bank                127
# Maruti Suzuki            117
# ICICI Bank               116
# ITC                      113
# Larsen                   113
# IndusInd Bank            105
# Infosys                   96
# Reliance                  95
# SBI                       93
# HDFC                      92
# Kotak Mahindra            90
# Tata Motors               79
# HCL Tech                  77
# IOC                       77
# Sun Pharma                75
# Power Grid Corp           72
# Hero Motocorp             68
# Axis Bank                 65
# Hindalco                  65
# M&M;                      64
# Tata Steel                63
# UltraTechCement           62
# Vedanta                   59
# Britannia                 57
# Yes Bank                  54
# Petronet LNG              54
# Bharat Elec               52
# NTPC                      51
# BPCL                      49
# Eicher Motors             49
# ...                      ...
# Action Const               2
# C & C Construct            2
# Alembic Pharma             2
# DLF                        2
# IRB Infra                  2
# Sintex Ind                 2
# GE Shipping                2
# HPL Electric &             2
# Ceat                       2
# PSP Projects               2
# Finolex Cables             2
# Balkrishna Ind             2
# GTPL Hathway               2
# JK Bank                    2
# Chennai Petro              2
# Navneet                    2
# L&T; Technology            2
# Power Finance              2
# Automotive Axle            2
# Godrej Prop                2
# Escorts                    2
# Polaris Consult            2
# Kirloskar Ind              2
# Apar Ind                   2
# Indoco Remedies            2
# Kalpataru Power            2
# Navkar Corp                2
# Pennar Eng                 2
# GSFC                       1
# Cosmo Films                1
#
# [351 rows x 1 columns]

# %%
df_final.columns
# Out:
# Index([u'Equity'], dtype='object')

# %%
df_final['stock_name'] = df_final.index

# %%
df_final.columns
# Out:
# Index([u'Equity', u'stock_name'], dtype='object')

# %%
df_final.rename(columns={'Equity':'stock_count'})
# Out:
#                  stock_count       stock_name
# HDFC Bank                127        HDFC Bank
# Maruti Suzuki            117    Maruti Suzuki
# ICICI Bank               116       ICICI Bank
# ITC                      113              ITC
# Larsen                   113           Larsen
# IndusInd Bank            105    IndusInd Bank
# Infosys                   96          Infosys
# Reliance                  95         Reliance
# SBI                       93              SBI
# HDFC                      92             HDFC
# Kotak Mahindra            90   Kotak Mahindra
# Tata Motors               79      Tata Motors
# HCL Tech                  77         HCL Tech
# IOC                       77              IOC
# Sun Pharma                75       Sun Pharma
# Power Grid Corp           72  Power Grid Corp
# Hero Motocorp             68    Hero Motocorp
# Axis Bank                 65        Axis Bank
# Hindalco                  65         Hindalco
# M&M;                      64             M&M;
# Tata Steel                63       Tata Steel
# UltraTechCement           62  UltraTechCement
# Vedanta                   59          Vedanta
# Britannia                 57        Britannia
# Yes Bank                  54         Yes Bank
# Petronet LNG              54     Petronet LNG
# Bharat Elec               52      Bharat Elec
# NTPC                      51             NTPC
# BPCL                      49             BPCL
# Eicher Motors             49    Eicher Motors
# ...                      ...              ...
# Action Const               2     Action Const
# C & C Construct            2  C & C Construct
# Alembic Pharma             2   Alembic Pharma
# DLF                        2              DLF
# IRB Infra                  2        IRB Infra
# Sintex Ind                 2       Sintex Ind
# GE Shipping                2      GE Shipping
# HPL Electric &             2  HPL Electric &
# Ceat                       2             Ceat
# PSP Projects               2     PSP Projects
# Finolex Cables             2   Finolex Cables
# Balkrishna Ind             2   Balkrishna Ind
# GTPL Hathway               2     GTPL Hathway
# JK Bank                    2          JK Bank
# Chennai Petro              2    Chennai Petro
# Navneet                    2          Navneet
# L&T; Technology            2  L&T; Technology
# Power Finance              2    Power Finance
# Automotive Axle            2  Automotive Axle
# Godrej Prop                2      Godrej Prop
# Escorts                    2          Escorts
# Polaris Consult            2  Polaris Consult
# Kirloskar Ind              2    Kirloskar Ind
# Apar Ind                   2         Apar Ind
# Indoco Remedies            2  Indoco Remedies
# Kalpataru Power            2  Kalpataru Power
# Navkar Corp                2      Navkar Corp
# Pennar Eng                 2       Pennar Eng
# GSFC                       1             GSFC
# Cosmo Films                1      Cosmo Films
#
# [351 rows x 2 columns]

# %%
df_for_save = pd.merge(df_final,df_equity_sector_new,on='stock_name',how='inner')

# %%
df_for_save.rename(columns={'Equity_x':'stock_count','Equity_y':'stock_name2'})
# Out:
#      stock_count       stock_name      stock_name2  \
# 0            127        HDFC Bank        HDFC Bank
# 1            117    Maruti Suzuki    Maruti Suzuki
# 2            116       ICICI Bank       ICICI Bank
# 3            113              ITC              ITC
# 4            113           Larsen           Larsen
# 5            105    IndusInd Bank    IndusInd Bank
# 6             96          Infosys          Infosys
# 7             95         Reliance         Reliance
# 8             93              SBI              SBI
# 9             92             HDFC             HDFC
# 10            90   Kotak Mahindra   Kotak Mahindra
# 11            79      Tata Motors      Tata Motors
# 12            77         HCL Tech         HCL Tech
# 13            77              IOC              IOC
# 14            75       Sun Pharma       Sun Pharma
# 15            72  Power Grid Corp  Power Grid Corp
# 16            68    Hero Motocorp    Hero Motocorp
# 17            65        Axis Bank        Axis Bank
# 18            65         Hindalco         Hindalco
# 19            64             M&M;             M&M;
# 20            63       Tata Steel       Tata Steel
# 21            62  UltraTechCement  UltraTechCement
# 22            59          Vedanta          Vedanta
# 23            57        Britannia        Britannia
# 24            54         Yes Bank         Yes Bank
# 25            54     Petronet LNG     Petronet LNG
# 26            52      Bharat Elec      Bharat Elec
# 27            51             NTPC             NTPC
# 28            49             BPCL             BPCL
# 29            49    Eicher Motors    Eicher Motors
# ..           ...              ...              ...
# 321            2     Action Const     Action Const
# 322            2  C & C Construct  C & C Construct
# 323            2   Alembic Pharma   Alembic Pharma
# 324            2              DLF              DLF
# 325            2        IRB Infra        IRB Infra
# 326            2       Sintex Ind       Sintex Ind
# 327            2      GE Shipping      GE Shipping
# 328            2  HPL Electric &   HPL Electric &
# 329            2             Ceat             Ceat
# 330            2     PSP Projects     PSP Projects
# 331            2   Finolex Cables   Finolex Cables
# 332            2   Balkrishna Ind   Balkrishna Ind
# 333            2     GTPL Hathway     GTPL Hathway
# 334            2          JK Bank          JK Bank
# 335            2    Chennai Petro    Chennai Petro
# 336            2          Navneet          Navneet
# 337            2  L&T; Technology  L&T; Technology
# 338            2    Power Finance    Power Finance
# 339            2  Automotive Axle  Automotive Axle
# 340            2      Godrej Prop      Godrej Prop
# 341            2          Escorts          Escorts
# 342            2  Polaris Consult  Polaris Consult
# 343            2    Kirloskar Ind    Kirloskar Ind
# 344            2         Apar Ind         Apar Ind
# 345            2  Indoco Remedies  Indoco Remedies
# 346            2  Kalpataru Power  Kalpataru Power
# 347            2      Navkar Corp      Navkar Corp
# 348            2       Pennar Eng       Pennar Eng
# 349            1             GSFC             GSFC
# 350            1      Cosmo Films      Cosmo Films
#
#                            Sector
# 0    Banking & Financial Services
# 1                      Automotive
# 2    Banking & Financial Services
# 3                         Tobacco
# 4     Engineering & Capital Goods
# 5    Banking & Financial Services
# 6          Information Technology
# 7                       Oil & Gas
# 8    Banking & Financial Services
# 9    Banking & Financial Services
# 10   Banking & Financial Services
# 11                     Automotive
# 12         Information Technology
# 13                      Oil & Gas
# 14                Pharmaceuticals
# 15                      Utilities
# 16                     Automotive
# 17   Banking & Financial Services
# 18                Metals & Mining
# 19                     Automotive
# 20                Metals & Mining
# 21          Cement & Construction
# 22                Metals & Mining
# 23               Food & Beverages
# 24   Banking & Financial Services
# 25                      Oil & Gas
# 26                  Manufacturing
# 27                      Utilities
# 28                      Oil & Gas
# 29                     Automotive
# ..                            ...
# 321   Engineering & Capital Goods
# 322         Cement & Construction
# 323               Pharmaceuticals
# 324          Retail & Real Estate
# 325   Engineering & Capital Goods
# 326                 Conglomerates
# 327                      Services
# 328   Engineering & Capital Goods
# 329                    Automotive
# 330         Cement & Construction
# 331             Telecommunication
# 332                    Automotive
# 333         Media & Entertainment
# 334  Banking & Financial Services
# 335                     Oil & Gas
# 336                 Miscellaneous
# 337        Information Technology
# 338  Banking & Financial Services
# 339                    Automotive
# 340          Retail & Real Estate
# 341                    Automotive
# 342        Information Technology
# 343   Engineering & Capital Goods
# 344                 Miscellaneous
# 345               Pharmaceuticals
# 346   Engineering & Capital Goods
# 347                      Services
# 348                 Miscellaneous
# 349                     Chemicals
# 350                 Manufacturing
#
# [351 rows x 4 columns]

# %%
df_for_save.to_csv('stockcount_SmallCap.csv')
